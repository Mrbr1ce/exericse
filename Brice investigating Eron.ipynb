# %% [markdown]
# # Libraries

# %%
# For reading, and transforming data
import pandas as pd 

# For creating network graphs 
import networkx as nx

# To use shortest path and clique-finding algorithms 
from networkx.algorithms import approximation

# For basic mathematical calculations
import math 


# For visualising our networks
import matplotlib.pyplot as plt

# Specifically, for interactive visualisations
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.graph_objs import *
from plotly.offline import plot as offpy

# %% [markdown]
# # Read the data and explore graphs properties

# %%
# read the data using pandas
enron = pd.read_csv('enron_emails.csv')

# first 5 rows
enron.head()
# Out:
#                from           to
# 0      greg.whalley     k..allen
# 1    louise.kitchen     k..allen
# 2    louise.kitchen     k..allen
# 3  errol.mclaughlin  john.arnold
# 4      mike.grigsby  john.arnold

# %%
type(enron)
# Out:
# pandas.core.frame.DataFrame

# %%
# Convert datafrrame into networkx graph object

# Create_using paramenter to specify directed or undirected

g = nx.from_pandas_edgelist(enron, source = 'from', target = 'to', create_using = nx.DiGraph())
g

# %%
# check fro sanity that it is directed 
nx.is_directed(g)
# Out:
# True

# %%
# Check out unique nodes in my network - as a list!
list(g.nodes())
# Out:
# ['greg.whalley',
#  'k..allen',
#  'louise.kitchen',
#  'errol.mclaughlin',
#  'john.arnold',
#  'mike.grigsby',
#  'john.griffith',
#  'dutch.quigley',
#  's..shively',
#  'richard.shapiro',
#  'harry.arora',
#  'sally.beck',
#  'matthew.lenhart',
#  'eric.bass',
#  'a..martin',
#  'm..love',
#  'monique.sanchez',
#  'charles.weldon',
#  'jeff.king',
#  'don.baughman',
#  'w..delainey',
#  'w..white',
#  'rod.hayslett',
#  'rick.buy',
#  'm..presto',
#  'robert.benson',
#  'dana.davis',
#  'joe.quenet',
#  'susan.scott',
#  'michelle.lokay',
#  'lynn.blair',
#  'lindy.donoho',
#  'shelley.corman',
#  'kimberly.watson',
#  'bill.rapp',
#  'scott.neal',
#  'f..brawner',
#  'jim.schwieger',
#  'vladi.pimenov',
#  'andrea.ring',
#  'l..mims',
#  'j.kaminski',
#  'j..kean',
#  'a..shankman',
#  'stanley.horton',
#  'kenneth.lay',
#  'f..campbell',
#  'joe.stepenovitch',
#  'd..thomas',
#  'mike.carson',
#  'eric.saibi',
#  'j..sturm',
#  'michelle.cash',
#  'teb.lokey',
#  'tracy.geaccone',
#  'kevin.hyatt',
#  'darrell.schoolcraft',
#  'd..steffes',
#  'cara.semperger',
#  'sean.crandall',
#  'cooper.richey',
#  'diana.scholtes',
#  'stephanie.panus',
#  'matt.motley',
#  'jeff.dasovich',
#  'barry.tycholiz',
#  'b..sanders',
#  'bill.williams',
#  'craig.dean',
#  'ryan.slinger',
#  'lisa.gang',
#  'geir.solberg',
#  'doug.gilbert-smith',
#  'benjamin.rogers',
#  'james.derrick',
#  "paul.y'barbo",
#  'mark.mcconnell',
#  'tom.donohoe',
#  'chris.germany',
#  'john.zufferli',
#  'chris.dorland',
#  'frank.ermis',
#  'kam.keiser',
#  'martin.cuilla',
#  'jay.reitmeyer',
#  'jason.wolfe',
#  'l..gay',
#  'mark.whitt',
#  'j..farmer',
#  'm..forney',
#  'judy.townsend',
#  'scott.hendrickson',
#  'john.hodge',
#  'susan.bailey',
#  'c..giron',
#  'e..haedicke',
#  'legal <.taylor@',
#  'gerald.nemec',
#  'danny.mccarty',
#  'sara.shackleton',
#  'marie.heard',
#  'tana.jones',
#  'elizabeth.sager',
#  'brad.mckay',
#  'juan.hernandez',
#  'debra.perlingiere',
#  'kay.mann',
#  'keith.holst',
#  'mike.swerzbin',
#  'peter.keavey',
#  'tori.kuykendall',
#  'lavorato',
#  'robert.badeer',
#  'jonathan.mckay',
#  'w..pereira',
#  'h..lewis',
#  't..lucci',
#  'mike.maggi',
#  'larry.may',
#  'joe.parks',
#  'andy.zipper',
#  'albert.meyers',
#  'theresa.staab',
#  'kevin.ruscitti',
#  'phillip.platter',
#  'holden.salisbury',
#  'jeff.skilling',
#  'matt.smith',
#  'geoff.storey',
#  'kim.ward',
#  'jason.williams']

# %%
# Checkout edges b- but now as a list of tubes
list(g.edges())
# Out:
# [('greg.whalley', 'k..allen'),
#  ('greg.whalley', 'rick.buy'),
#  ('k..allen', 'keith.holst'),
#  ('k..allen', 'kam.keiser'),
#  ('k..allen', 'lavorato'),
#  ('k..allen', 'h..lewis'),
#  ('k..allen', 'a..martin'),
#  ('k..allen', 'scott.neal'),
#  ('k..allen', 'dutch.quigley'),
#  ('k..allen', 'greg.whalley'),
#  ('louise.kitchen', 'k..allen'),
#  ('louise.kitchen', 'john.arnold'),
#  ('louise.kitchen', 'harry.arora'),
#  ('louise.kitchen', 'sally.beck'),
#  ('louise.kitchen', 'robert.benson'),
#  ('louise.kitchen', 'f..brawner'),
#  ('louise.kitchen', 'rick.buy'),
#  ('louise.kitchen', 'mike.carson'),
#  ('louise.kitchen', 'doug.gilbert-smith'),
#  ('louise.kitchen', 'mike.grigsby'),
#  ('louise.kitchen', 'e..haedicke'),
#  ('louise.kitchen', 'lavorato'),
#  ('louise.kitchen', 'a..martin'),
#  ('louise.kitchen', 'larry.may'),
#  ('louise.kitchen', 'l..mims'),
#  ('louise.kitchen', 'scott.neal'),
#  ('louise.kitchen', 'gerald.nemec'),
#  ('louise.kitchen', 'm..presto'),
#  ('louise.kitchen', 'elizabeth.sager'),
#  ('louise.kitchen', 'sara.shackleton'),
#  ('louise.kitchen', 's..shively'),
#  ('louise.kitchen', 'd..steffes'),
#  ('louise.kitchen', 'geoff.storey'),
#  ('louise.kitchen', 'mike.swerzbin'),
#  ('louise.kitchen', 'legal <.taylor@'),
#  ('louise.kitchen', 'barry.tycholiz'),
#  ('louise.kitchen', 'greg.whalley'),
#  ('louise.kitchen', 'w..white'),
#  ('louise.kitchen', 'andy.zipper'),
#  ('errol.mclaughlin', 'john.arnold'),
#  ('errol.mclaughlin', 'kam.keiser'),
#  ('errol.mclaughlin', 'mike.maggi'),
#  ('errol.mclaughlin', 'larry.may'),
#  ('errol.mclaughlin', 'dutch.quigley'),
#  ('errol.mclaughlin', 'andy.zipper'),
#  ('john.arnold', 'peter.keavey'),
#  ('john.arnold', 'lavorato'),
#  ('john.arnold', 'mike.maggi'),
#  ('john.arnold', 'larry.may'),
#  ('john.arnold', 'errol.mclaughlin'),
#  ('john.arnold', 'dutch.quigley'),
#  ('john.arnold', 'kim.ward'),
#  ('john.arnold', 'andy.zipper'),
#  ('mike.grigsby', 'john.arnold'),
#  ('mike.grigsby', 'frank.ermis'),
#  ('mike.grigsby', 'l..gay'),
#  ('mike.grigsby', 'john.hodge'),
#  ('mike.grigsby', 'keith.holst'),
#  ('mike.grigsby', 'kam.keiser'),
#  ('mike.grigsby', 'tori.kuykendall'),
#  ('mike.grigsby', 'lavorato'),
#  ('mike.grigsby', 'matthew.lenhart'),
#  ('mike.grigsby', 'a..martin'),
#  ('mike.grigsby', 'matt.motley'),
#  ('mike.grigsby', 'vladi.pimenov'),
#  ('mike.grigsby', 'jay.reitmeyer'),
#  ('mike.grigsby', 'monique.sanchez'),
#  ('mike.grigsby', 'susan.scott'),
#  ('mike.grigsby', 's..shively'),
#  ('mike.grigsby', 'matt.smith'),
#  ('mike.grigsby', 'j..sturm'),
#  ('mike.grigsby', 'mike.swerzbin'),
#  ('mike.grigsby', 'barry.tycholiz'),
#  ('mike.grigsby', 'kim.ward'),
#  ('mike.grigsby', 'jason.wolfe'),
#  ('john.griffith', 'john.arnold'),
#  ('john.griffith', 'peter.keavey'),
#  ('john.griffith', 'mike.maggi'),
#  ('john.griffith', 'larry.may'),
#  ('john.griffith', 'brad.mckay'),
#  ('john.griffith', 'vladi.pimenov'),
#  ('john.griffith', 'dutch.quigley'),
#  ('john.griffith', 'andy.zipper'),
#  ('dutch.quigley', 'john.arnold'),
#  ('dutch.quigley', 'mike.maggi'),
#  ('dutch.quigley', 'errol.mclaughlin'),
#  ('dutch.quigley', 'susan.scott'),
#  ('s..shively', 'john.arnold'),
#  ('s..shively', 'c..giron'),
#  ('s..shively', 'john.hodge'),
#  ('s..shively', 'lavorato'),
#  ('s..shively', 'a..martin'),
#  ('s..shively', 'l..mims'),
#  ('s..shively', 'scott.neal'),
#  ('s..shively', 'geoff.storey'),
#  ('richard.shapiro', 'harry.arora'),
#  ('richard.shapiro', 'jeff.dasovich'),
#  ('richard.shapiro', 'j..kean'),
#  ('richard.shapiro', 'lavorato'),
#  ('richard.shapiro', 'kenneth.lay'),
#  ('richard.shapiro', 'jeff.skilling'),
#  ('richard.shapiro', 'd..steffes'),
#  ('richard.shapiro', 'greg.whalley'),
#  ('harry.arora', 'w..white'),
#  ('harry.arora', 'andy.zipper'),
#  ('sally.beck', 'harry.arora'),
#  ('sally.beck', 'rick.buy'),
#  ('sally.beck', 'tom.donohoe'),
#  ('sally.beck', 'juan.hernandez'),
#  ('sally.beck', 'peter.keavey'),
#  ('sally.beck', 'kam.keiser'),
#  ('sally.beck', 'louise.kitchen'),
#  ('sally.beck', 'lavorato'),
#  ('sally.beck', 'kenneth.lay'),
#  ('sally.beck', 'a..martin'),
#  ('sally.beck', 'larry.may'),
#  ('sally.beck', 'jay.reitmeyer'),
#  ('sally.beck', 'benjamin.rogers'),
#  ('sally.beck', 'eric.saibi'),
#  ('sally.beck', 'j..sturm'),
#  ('sally.beck', 'greg.whalley'),
#  ('sally.beck', 'w..white'),
#  ('sally.beck', 'jason.wolfe'),
#  ('matthew.lenhart', 'eric.bass'),
#  ('matthew.lenhart', 'frank.ermis'),
#  ('matthew.lenhart', 'l..gay'),
#  ('matthew.lenhart', 'mike.grigsby'),
#  ('matthew.lenhart', 'kam.keiser'),
#  ('matthew.lenhart', 'susan.scott'),
#  ('matthew.lenhart', 'matt.smith'),
#  ('matthew.lenhart', 'jason.wolfe'),
#  ('eric.bass', 'j..farmer'),
#  ('eric.bass', 'm..love'),
#  ('eric.bass', 'a..martin'),
#  ('eric.bass', 'joe.parks'),
#  ('eric.bass', 'charles.weldon'),
#  ('eric.bass', 'jason.wolfe'),
#  ('a..martin', 'eric.bass'),
#  ('a..martin', 'lavorato'),
#  ('a..martin', 'joe.parks'),
#  ('a..martin', 'judy.townsend'),
#  ('m..love', 'eric.bass'),
#  ('m..love', 'c..giron'),
#  ('m..love', 'john.hodge'),
#  ('m..love', 'kam.keiser'),
#  ('m..love', 'errol.mclaughlin'),
#  ('m..love', 'vladi.pimenov'),
#  ('m..love', 'monique.sanchez'),
#  ('m..love', 'geoff.storey'),
#  ('m..love', 'jason.wolfe'),
#  ('monique.sanchez', 'eric.bass'),
#  ('monique.sanchez', 'peter.keavey'),
#  ('monique.sanchez', 'h..lewis'),
#  ('monique.sanchez', 'larry.may'),
#  ('monique.sanchez', 'matt.motley'),
#  ('monique.sanchez', 'scott.neal'),
#  ('monique.sanchez', 'dutch.quigley'),
#  ('monique.sanchez', 'jay.reitmeyer'),
#  ('monique.sanchez', 'susan.scott'),
#  ('monique.sanchez', 'matt.smith'),
#  ('monique.sanchez', 'jason.wolfe'),
#  ('charles.weldon', 'eric.bass'),
#  ('charles.weldon', 'a..martin'),
#  ('charles.weldon', 'joe.parks'),
#  ('charles.weldon', 'matt.smith'),
#  ('jeff.king', 'don.baughman'),
#  ('jeff.king', 'doug.gilbert-smith'),
#  ('don.baughman', 'f..campbell'),
#  ('don.baughman', 'm..forney'),
#  ('don.baughman', 'juan.hernandez'),
#  ('don.baughman', 'joe.stepenovitch'),
#  ('don.baughman', 'd..thomas'),
#  ('w..delainey', 'sally.beck'),
#  ('w..delainey', 'rick.buy'),
#  ('w..delainey', 'lavorato'),
#  ('w..delainey', 'kenneth.lay'),
#  ('w..delainey', 'greg.whalley'),
#  ('w..white', 'sally.beck'),
#  ('w..white', 'robert.benson'),
#  ('w..white', 'kam.keiser'),
#  ('w..white', 'lavorato'),
#  ('w..white', 'elizabeth.sager'),
#  ('w..white', 'geoff.storey'),
#  ('w..white', 'charles.weldon'),
#  ('w..white', 'john.zufferli'),
#  ('rod.hayslett', 'sally.beck'),
#  ('rod.hayslett', 'shelley.corman'),
#  ('rod.hayslett', 'lindy.donoho'),
#  ('rod.hayslett', 'tracy.geaccone'),
#  ('rod.hayslett', 'stanley.horton'),
#  ('rod.hayslett', 'teb.lokey'),
#  ('rod.hayslett', 'danny.mccarty'),
#  ('rod.hayslett', 'bill.rapp'),
#  ('rod.hayslett', 'jeff.skilling'),
#  ('rod.hayslett', 'kimberly.watson'),
#  ('rick.buy', 'sally.beck'),
#  ('rick.buy', 'e..haedicke'),
#  ('rick.buy', 'kenneth.lay'),
#  ('rick.buy', 'greg.whalley'),
#  ('m..presto', 'robert.benson'),
#  ('m..presto', 'rick.buy'),
#  ('m..presto', 'm..forney'),
#  ('m..presto', 'doug.gilbert-smith'),
#  ('m..presto', 'louise.kitchen'),
#  ('m..presto', 'lavorato'),
#  ('m..presto', 'stephanie.panus'),
#  ('m..presto', 'elizabeth.sager'),
#  ('m..presto', 'j..sturm'),
#  ('m..presto', 'd..thomas'),
#  ('m..presto', 'w..white'),
#  ('m..presto', 'andy.zipper'),
#  ('dana.davis', 'robert.benson'),
#  ('dana.davis', 'benjamin.rogers'),
#  ('dana.davis', 'd..steffes'),
#  ('joe.quenet', 'robert.benson'),
#  ('susan.scott', 'robert.benson'),
#  ('susan.scott', 'f..campbell'),
#  ('susan.scott', 'juan.hernandez'),
#  ('susan.scott', 'joe.stepenovitch'),
#  ('susan.scott', 'barry.tycholiz'),
#  ('michelle.lokay', 'lynn.blair'),
#  ('michelle.lokay', 'shelley.corman'),
#  ('michelle.lokay', 'lindy.donoho'),
#  ('michelle.lokay', 'tracy.geaccone'),
#  ('michelle.lokay', 'rod.hayslett'),
#  ('michelle.lokay', 'teb.lokey'),
#  ('michelle.lokay', 'mark.mcconnell'),
#  ('michelle.lokay', 'bill.rapp'),
#  ('michelle.lokay', 'darrell.schoolcraft'),
#  ('michelle.lokay', 'kimberly.watson'),
#  ('michelle.lokay', "paul.y'barbo"),
#  ('lynn.blair', 'shelley.corman'),
#  ('lynn.blair', 'lindy.donoho'),
#  ('lynn.blair', 'stanley.horton'),
#  ('lynn.blair', 'michelle.lokay'),
#  ('lynn.blair', 'danny.mccarty'),
#  ('lynn.blair', 'bill.rapp'),
#  ('lynn.blair', 'darrell.schoolcraft'),
#  ('lynn.blair', 'kimberly.watson'),
#  ('lindy.donoho', 'lynn.blair'),
#  ('lindy.donoho', 'shelley.corman'),
#  ('lindy.donoho', 'tracy.geaccone'),
#  ('lindy.donoho', 'rod.hayslett'),
#  ('lindy.donoho', 'teb.lokey'),
#  ('lindy.donoho', 'bill.rapp'),
#  ('lindy.donoho', 'kimberly.watson'),
#  ('lindy.donoho', "paul.y'barbo"),
#  ('shelley.corman', 'lynn.blair'),
#  ('shelley.corman', 'lindy.donoho'),
#  ('shelley.corman', 'kevin.hyatt'),
#  ('shelley.corman', 'teb.lokey'),
#  ('shelley.corman', 'danny.mccarty'),
#  ('shelley.corman', 'darrell.schoolcraft'),
#  ('shelley.corman', 'kimberly.watson'),
#  ('kimberly.watson', 'lynn.blair'),
#  ('kimberly.watson', 'shelley.corman'),
#  ('kimberly.watson', 'lindy.donoho'),
#  ('kimberly.watson', 'tracy.geaccone'),
#  ('kimberly.watson', 'michelle.lokay'),
#  ('kimberly.watson', 'teb.lokey'),
#  ('kimberly.watson', 'mark.mcconnell'),
#  ('kimberly.watson', 'bill.rapp'),
#  ('kimberly.watson', 'darrell.schoolcraft'),
#  ('kimberly.watson', "paul.y'barbo"),
#  ('bill.rapp', 'lynn.blair'),
#  ('bill.rapp', 'lindy.donoho'),
#  ('bill.rapp', 'michelle.lokay'),
#  ('bill.rapp', 'teb.lokey'),
#  ('bill.rapp', 'kimberly.watson'),
#  ('bill.rapp', "paul.y'barbo"),
#  ('scott.neal', 'f..brawner'),
#  ('scott.neal', 'john.hodge'),
#  ('scott.neal', 'peter.keavey'),
#  ('scott.neal', 'lavorato'),
#  ('scott.neal', 'h..lewis'),
#  ('scott.neal', 'a..martin'),
#  ('scott.neal', 'brad.mckay'),
#  ('scott.neal', 'andrea.ring'),
#  ('scott.neal', 's..shively'),
#  ('scott.neal', 'judy.townsend'),
#  ('f..brawner', 'lavorato'),
#  ('f..brawner', 'a..martin'),
#  ('jim.schwieger', 'f..brawner'),
#  ('jim.schwieger', 'john.hodge'),
#  ('jim.schwieger', 'kenneth.lay'),
#  ('jim.schwieger', 'a..martin'),
#  ('jim.schwieger', 'larry.may'),
#  ('jim.schwieger', 'joe.parks'),
#  ('jim.schwieger', 'greg.whalley'),
#  ('vladi.pimenov', 'f..brawner'),
#  ('vladi.pimenov', 'dutch.quigley'),
#  ('andrea.ring', 'f..brawner'),
#  ('l..mims', 'f..brawner'),
#  ('l..mims', 'debra.perlingiere'),
#  ('l..mims', 'geoff.storey'),
#  ('j.kaminski', 'rick.buy'),
#  ('j.kaminski', 'lavorato'),
#  ('j.kaminski', 'greg.whalley'),
#  ('j..kean', 'rick.buy'),
#  ('j..kean', 'michelle.cash'),
#  ('j..kean', 'jeff.dasovich'),
#  ('j..kean', 'james.derrick'),
#  ('j..kean', 'e..haedicke'),
#  ('j..kean', 'kenneth.lay'),
#  ('j..kean', 'd..steffes'),
#  ('j..kean', 'greg.whalley'),
#  ('a..shankman', 'rick.buy'),
#  ('a..shankman', 'e..haedicke'),
#  ('a..shankman', 'lavorato'),
#  ('a..shankman', 'kenneth.lay'),
#  ('a..shankman', 'greg.whalley'),
#  ('a..shankman', 'andy.zipper'),
#  ('stanley.horton', 'rick.buy'),
#  ('stanley.horton', 'shelley.corman'),
#  ('stanley.horton', 'lindy.donoho'),
#  ('stanley.horton', 'tracy.geaccone'),
#  ('stanley.horton', 'rod.hayslett'),
#  ('stanley.horton', 'kenneth.lay'),
#  ('stanley.horton', 'danny.mccarty'),
#  ('stanley.horton', 'jeff.skilling'),
#  ('stanley.horton', 'greg.whalley'),
#  ('kenneth.lay', 'rick.buy'),
#  ('kenneth.lay', 'e..haedicke'),
#  ('kenneth.lay', 'j..kean'),
#  ('kenneth.lay', 'jeff.skilling'),
#  ('kenneth.lay', 'greg.whalley'),
#  ('f..campbell', 'd..thomas'),
#  ('joe.stepenovitch', 'f..campbell'),
#  ('joe.stepenovitch', 'juan.hernandez'),
#  ('joe.stepenovitch', 'benjamin.rogers'),
#  ('joe.stepenovitch', 'd..thomas'),
#  ('d..thomas', 'f..campbell'),
#  ('d..thomas', 'benjamin.rogers'),
#  ('mike.carson', 'eric.saibi'),
#  ('eric.saibi', 'mike.carson'),
#  ('j..sturm', 'mike.carson'),
#  ('j..sturm', 'doug.gilbert-smith'),
#  ('j..sturm', 'a..martin'),
#  ('j..sturm', 'eric.saibi'),
#  ('j..sturm', 's..shively'),
#  ('michelle.cash', 'james.derrick'),
#  ('michelle.cash', 'e..haedicke'),
#  ('michelle.cash', 's..shively'),
#  ('teb.lokey', 'shelley.corman'),
#  ('teb.lokey', 'lindy.donoho'),
#  ('teb.lokey', 'tracy.geaccone'),
#  ('teb.lokey', 'darrell.schoolcraft'),
#  ('tracy.geaccone', 'shelley.corman'),
#  ('tracy.geaccone', 'lindy.donoho'),
#  ('tracy.geaccone', 'rod.hayslett'),
#  ('tracy.geaccone', 'teb.lokey'),
#  ('tracy.geaccone', 'kimberly.watson'),
#  ('kevin.hyatt', 'shelley.corman'),
#  ('kevin.hyatt', 'lindy.donoho'),
#  ('kevin.hyatt', 'tracy.geaccone'),
#  ('kevin.hyatt', 'rod.hayslett'),
#  ('kevin.hyatt', 'kenneth.lay'),
#  ('kevin.hyatt', 'michelle.lokay'),
#  ('kevin.hyatt', 'teb.lokey'),
#  ('kevin.hyatt', 'bill.rapp'),
#  ('kevin.hyatt', 'darrell.schoolcraft'),
#  ('kevin.hyatt', 'kimberly.watson'),
#  ('darrell.schoolcraft', 'shelley.corman'),
#  ('darrell.schoolcraft', 'lindy.donoho'),
#  ('darrell.schoolcraft', 'michelle.lokay'),
#  ('darrell.schoolcraft', 'teb.lokey'),
#  ('darrell.schoolcraft', 'mark.mcconnell'),
#  ('darrell.schoolcraft', 'kimberly.watson'),
#  ('d..steffes', 'shelley.corman'),
#  ('d..steffes', 'jeff.dasovich'),
#  ('d..steffes', 'doug.gilbert-smith'),
#  ('d..steffes', 'j.kaminski'),
#  ('d..steffes', 'elizabeth.sager'),
#  ('d..steffes', 'b..sanders'),
#  ('d..steffes', 'richard.shapiro'),
#  ('cara.semperger', 'sean.crandall'),
#  ('cara.semperger', 'craig.dean'),
#  ('cara.semperger', 'albert.meyers'),
#  ('cara.semperger', 'phillip.platter'),
#  ('cara.semperger', 'holden.salisbury'),
#  ('cara.semperger', 'diana.scholtes'),
#  ('cara.semperger', 'ryan.slinger'),
#  ('cara.semperger', 'geir.solberg'),
#  ('cara.semperger', 'mike.swerzbin'),
#  ('cara.semperger', 'bill.williams'),
#  ('cooper.richey', 'sean.crandall'),
#  ('diana.scholtes', 'sean.crandall'),
#  ('diana.scholtes', 'phillip.platter'),
#  ('diana.scholtes', 'holden.salisbury'),
#  ('diana.scholtes', 'mike.swerzbin'),
#  ('stephanie.panus', 'sean.crandall'),
#  ('stephanie.panus', 'chris.germany'),
#  ('stephanie.panus', 'doug.gilbert-smith'),
#  ('stephanie.panus', 'marie.heard'),
#  ('stephanie.panus', 'john.hodge'),
#  ('stephanie.panus', 'tana.jones'),
#  ('stephanie.panus', 'l..mims'),
#  ('stephanie.panus', 'gerald.nemec'),
#  ('stephanie.panus', 'debra.perlingiere'),
#  ('stephanie.panus', 'elizabeth.sager'),
#  ('stephanie.panus', 'sara.shackleton'),
#  ('stephanie.panus', 'j..sturm'),
#  ('stephanie.panus', 'legal <.taylor@'),
#  ('matt.motley', 'sean.crandall'),
#  ('matt.motley', 'mike.swerzbin'),
#  ('jeff.dasovich', 'lindy.donoho'),
#  ('jeff.dasovich', 'j..kean'),
#  ('jeff.dasovich', 'teb.lokey'),
#  ('jeff.dasovich', 'b..sanders'),
#  ('jeff.dasovich', 'richard.shapiro'),
#  ('jeff.dasovich', 'jeff.skilling'),
#  ('jeff.dasovich', 'd..steffes'),
#  ('jeff.dasovich', 'barry.tycholiz'),
#  ('barry.tycholiz', 'jeff.dasovich'),
#  ('barry.tycholiz', 'a..martin'),
#  ('barry.tycholiz', 'gerald.nemec'),
#  ('barry.tycholiz', 'kim.ward'),
#  ('barry.tycholiz', 'mark.whitt'),
#  ('b..sanders', 'jeff.dasovich'),
#  ('b..sanders', 'e..haedicke'),
#  ('b..sanders', 'lavorato'),
#  ('bill.williams', 'craig.dean'),
#  ('bill.williams', 'albert.meyers'),
#  ('bill.williams', 'holden.salisbury'),
#  ('bill.williams', 'geir.solberg'),
#  ('craig.dean', 'holden.salisbury'),
#  ('craig.dean', 'bill.williams'),
#  ('ryan.slinger', 'craig.dean'),
#  ('ryan.slinger', 'holden.salisbury'),
#  ('ryan.slinger', 'geir.solberg'),
#  ('ryan.slinger', 'bill.williams'),
#  ('lisa.gang', 'craig.dean'),
#  ('lisa.gang', 'holden.salisbury'),
#  ('geir.solberg', 'craig.dean'),
#  ('geir.solberg', 'holden.salisbury'),
#  ('geir.solberg', 'bill.williams'),
#  ('doug.gilbert-smith', 'craig.dean'),
#  ('doug.gilbert-smith', 'm..forney'),
#  ('doug.gilbert-smith', 'jeff.king'),
#  ('doug.gilbert-smith', 'a..martin'),
#  ('doug.gilbert-smith', 'eric.saibi'),
#  ('doug.gilbert-smith', 'd..steffes'),
#  ('doug.gilbert-smith', 'w..white'),
#  ('doug.gilbert-smith', 'bill.williams'),
#  ('benjamin.rogers', 'w..delainey'),
#  ('benjamin.rogers', 'kenneth.lay'),
#  ('james.derrick', 'e..haedicke'),
#  ('james.derrick', 'kenneth.lay'),
#  ('james.derrick', 'greg.whalley'),
#  ("paul.y'barbo", 'lindy.donoho'),
#  ("paul.y'barbo", 'l..gay'),
#  ("paul.y'barbo", 'gerald.nemec'),
#  ("paul.y'barbo", 'bill.rapp'),
#  ("paul.y'barbo", 'kimberly.watson'),
#  ('mark.mcconnell', 'lindy.donoho'),
#  ('mark.mcconnell', 'rod.hayslett'),
#  ('mark.mcconnell', 'teb.lokey'),
#  ('mark.mcconnell', 'bill.rapp'),
#  ('mark.mcconnell', 'darrell.schoolcraft'),
#  ('mark.mcconnell', 'kimberly.watson'),
#  ('mark.mcconnell', "paul.y'barbo"),
#  ('tom.donohoe', 'kenneth.lay'),
#  ('tom.donohoe', 'greg.whalley'),
#  ('chris.germany', 'tom.donohoe'),
#  ('chris.germany', 'scott.hendrickson'),
#  ('chris.germany', 'john.hodge'),
#  ('chris.germany', 'peter.keavey'),
#  ('chris.germany', 'scott.neal'),
#  ('chris.germany', 'joe.parks'),
#  ('chris.germany', 'vladi.pimenov'),
#  ('chris.germany', 'judy.townsend'),
#  ('john.zufferli', 'chris.dorland'),
#  ('john.zufferli', 'cooper.richey'),
#  ('chris.dorland', 'mike.grigsby'),
#  ('chris.dorland', 'jay.reitmeyer'),
#  ('frank.ermis', 'jay.reitmeyer'),
#  ('frank.ermis', 'jason.wolfe'),
#  ('kam.keiser', 'frank.ermis'),
#  ('kam.keiser', 'l..gay'),
#  ('kam.keiser', 'chris.germany'),
#  ('kam.keiser', 'c..giron'),
#  ('kam.keiser', 'mike.grigsby'),
#  ('kam.keiser', 'john.hodge'),
#  ('kam.keiser', 'keith.holst'),
#  ('kam.keiser', 'tori.kuykendall'),
#  ('kam.keiser', 'm..love'),
#  ('kam.keiser', 'errol.mclaughlin'),
#  ('kam.keiser', 'scott.neal'),
#  ('kam.keiser', 'vladi.pimenov'),
#  ('kam.keiser', 'jay.reitmeyer'),
#  ('kam.keiser', 's..shively'),
#  ('kam.keiser', 'matt.smith'),
#  ('kam.keiser', 'kim.ward'),
#  ('kam.keiser', 'w..white'),
#  ('kam.keiser', 'mark.whitt'),
#  ('kam.keiser', 'jason.wolfe'),
#  ('martin.cuilla', 'frank.ermis'),
#  ('martin.cuilla', 'h..lewis'),
#  ('martin.cuilla', 'brad.mckay'),
#  ('martin.cuilla', 'kevin.ruscitti'),
#  ('martin.cuilla', 'jason.williams'),
#  ('jay.reitmeyer', 'frank.ermis'),
#  ('jay.reitmeyer', 'mike.grigsby'),
#  ('jay.reitmeyer', 's..shively'),
#  ('jason.wolfe', 'frank.ermis'),
#  ('jason.wolfe', 'jay.reitmeyer'),
#  ('jason.wolfe', 'barry.tycholiz'),
#  ('l..gay', 'frank.ermis'),
#  ('l..gay', 'jay.reitmeyer'),
#  ('l..gay', 'kim.ward'),
#  ('mark.whitt', 'frank.ermis'),
#  ('mark.whitt', 'mike.grigsby'),
#  ('mark.whitt', 't..lucci'),
#  ('mark.whitt', 'gerald.nemec'),
#  ('mark.whitt', 'jay.reitmeyer'),
#  ('mark.whitt', 'theresa.staab'),
#  ('mark.whitt', 'barry.tycholiz'),
#  ('j..farmer', 'john.hodge'),
#  ('j..farmer', 'a..martin'),
#  ('j..farmer', 'gerald.nemec'),
#  ('m..forney', 'doug.gilbert-smith'),
#  ('m..forney', 'eric.saibi'),
#  ('judy.townsend', 'chris.germany'),
#  ('scott.hendrickson', 'chris.germany'),
#  ('scott.hendrickson', 'larry.may'),
#  ('scott.hendrickson', 'scott.neal'),
#  ('john.hodge', 'chris.germany'),
#  ('susan.bailey', 'chris.germany'),
#  ('susan.bailey', 'marie.heard'),
#  ('susan.bailey', 'tana.jones'),
#  ('susan.bailey', 'sara.shackleton'),
#  ('susan.bailey', 'legal <.taylor@'),
#  ('c..giron', 'm..love'),
#  ('c..giron', 's..shively'),
#  ('e..haedicke', 'tana.jones'),
#  ('e..haedicke', 'gerald.nemec'),
#  ('e..haedicke', 'elizabeth.sager'),
#  ('e..haedicke', 'b..sanders'),
#  ('legal <.taylor@', 'e..haedicke'),
#  ('legal <.taylor@', 'marie.heard'),
#  ('legal <.taylor@', 'john.hodge'),
#  ('legal <.taylor@', 'tana.jones'),
#  ('legal <.taylor@', 'elizabeth.sager'),
#  ('legal <.taylor@', 'sara.shackleton'),
#  ('gerald.nemec', 'e..haedicke'),
#  ('gerald.nemec', 'john.hodge'),
#  ('gerald.nemec', 't..lucci'),
#  ('gerald.nemec', 'joe.parks'),
#  ('gerald.nemec', 'debra.perlingiere'),
#  ('gerald.nemec', 'sara.shackleton'),
#  ('gerald.nemec', 'barry.tycholiz'),
#  ('gerald.nemec', 'kim.ward'),
#  ('gerald.nemec', 'mark.whitt'),
#  ('danny.mccarty', 'rod.hayslett'),
#  ('danny.mccarty', 'kenneth.lay'),
#  ('sara.shackleton', 'marie.heard'),
#  ('sara.shackleton', 'john.hodge'),
#  ('sara.shackleton', 'tana.jones'),
#  ('sara.shackleton', 'stephanie.panus'),
#  ('sara.shackleton', 'elizabeth.sager'),
#  ('sara.shackleton', 'legal <.taylor@'),
#  ('sara.shackleton', 'kim.ward'),
#  ('marie.heard', 'john.hodge'),
#  ('marie.heard', 'tana.jones'),
#  ('marie.heard', 'gerald.nemec'),
#  ('marie.heard', 'elizabeth.sager'),
#  ('marie.heard', 'sara.shackleton'),
#  ('marie.heard', 'legal <.taylor@'),
#  ('tana.jones', 'marie.heard'),
#  ('tana.jones', 'john.hodge'),
#  ('tana.jones', 'stephanie.panus'),
#  ('tana.jones', 'sara.shackleton'),
#  ('tana.jones', 'legal <.taylor@'),
#  ('elizabeth.sager', 'marie.heard'),
#  ('elizabeth.sager', 'legal <.taylor@'),
#  ('elizabeth.sager', 'd..thomas'),
#  ('brad.mckay', 'scott.hendrickson'),
#  ('brad.mckay', 'peter.keavey'),
#  ('brad.mckay', 'larry.may'),
#  ('debra.perlingiere', 'john.hodge'),
#  ('debra.perlingiere', 'l..mims'),
#  ('debra.perlingiere', 'scott.neal'),
#  ('debra.perlingiere', 'gerald.nemec'),
#  ('debra.perlingiere', 'barry.tycholiz'),
#  ('debra.perlingiere', 'kim.ward'),
#  ('debra.perlingiere', 'mark.whitt'),
#  ('debra.perlingiere', 'jason.williams'),
#  ('kay.mann', 'john.hodge'),
#  ('kay.mann', 'gerald.nemec'),
#  ('kay.mann', 'joe.parks'),
#  ('kay.mann', 'debra.perlingiere'),
#  ('kay.mann', 'elizabeth.sager'),
#  ('kay.mann', 'sara.shackleton'),
#  ('keith.holst', 'kam.keiser'),
#  ('keith.holst', 'lavorato'),
#  ('keith.holst', 'susan.scott'),
#  ('keith.holst', 'jason.wolfe'),
#  ('mike.swerzbin', 'keith.holst'),
#  ('tori.kuykendall', 'jay.reitmeyer'),
#  ('tori.kuykendall', 'monique.sanchez'),
#  ('tori.kuykendall', 'susan.scott'),
#  ('robert.badeer', 'lavorato'),
#  ('jonathan.mckay', 'lavorato'),
#  ('jonathan.mckay', 'brad.mckay'),
#  ('jonathan.mckay', 'scott.neal'),
#  ('jonathan.mckay', 'vladi.pimenov'),
#  ('jonathan.mckay', 'andy.zipper'),
#  ('w..pereira', 'kenneth.lay'),
#  ('h..lewis', 'greg.whalley'),
#  ('t..lucci', 'gerald.nemec'),
#  ('t..lucci', 'jay.reitmeyer'),
#  ('t..lucci', 'theresa.staab'),
#  ('t..lucci', 'barry.tycholiz'),
#  ('t..lucci', 'kim.ward'),
#  ('t..lucci', 'mark.whitt'),
#  ('mike.maggi', 'larry.may'),
#  ('larry.may', 'mike.maggi'),
#  ('larry.may', 'andy.zipper'),
#  ('joe.parks', 'a..martin'),
#  ('joe.parks', 'susan.scott'),
#  ('andy.zipper', 'a..martin'),
#  ('andy.zipper', 'larry.may'),
#  ('andy.zipper', 'errol.mclaughlin'),
#  ('andy.zipper', 'scott.neal'),
#  ('andy.zipper', 'vladi.pimenov'),
#  ('andy.zipper', 'legal <.taylor@'),
#  ('andy.zipper', 'greg.whalley'),
#  ('albert.meyers', 'ryan.slinger'),
#  ('albert.meyers', 'geir.solberg'),
#  ('albert.meyers', 'bill.williams'),
#  ('theresa.staab', 'gerald.nemec'),
#  ('theresa.staab', 'jay.reitmeyer'),
#  ('theresa.staab', 'susan.scott'),
#  ('theresa.staab', 'mark.whitt'),
#  ('kevin.ruscitti', 'joe.parks'),
#  ('phillip.platter', 'holden.salisbury')]

# %%
# Checkout degree of each node - the number of connections a nodes has
# direction augnostic
list(g.degree())
# Out:
# [('greg.whalley', 18),
#  ('k..allen', 10),
#  ('louise.kitchen', 31),
#  ('errol.mclaughlin', 11),
#  ('john.arnold', 14),
#  ('mike.grigsby', 28),
#  ('john.griffith', 8),
#  ('dutch.quigley', 10),
#  ('s..shively', 16),
#  ('richard.shapiro', 10),
#  ('harry.arora', 5),
#  ('sally.beck', 23),
#  ('matthew.lenhart', 9),
#  ('eric.bass', 11),
#  ('a..martin', 20),
#  ('m..love', 12),
#  ('monique.sanchez', 14),
#  ('charles.weldon', 6),
#  ('jeff.king', 3),
#  ('don.baughman', 6),
#  ('w..delainey', 6),
#  ('w..white', 14),
#  ('rod.hayslett', 17),
#  ('rick.buy', 14),
#  ('m..presto', 13),
#  ('robert.benson', 6),
#  ('dana.davis', 3),
#  ('joe.quenet', 1),
#  ('susan.scott', 13),
#  ('michelle.lokay', 16),
#  ('lynn.blair', 13),
#  ('lindy.donoho', 22),
#  ('shelley.corman', 18),
#  ('kimberly.watson', 21),
#  ('bill.rapp', 14),
#  ('scott.neal', 20),
#  ('f..brawner', 8),
#  ('jim.schwieger', 7),
#  ('vladi.pimenov', 9),
#  ('andrea.ring', 2),
#  ('l..mims', 7),
#  ('j.kaminski', 4),
#  ('j..kean', 11),
#  ('a..shankman', 6),
#  ('stanley.horton', 11),
#  ('kenneth.lay', 19),
#  ('f..campbell', 5),
#  ('joe.stepenovitch', 6),
#  ('d..thomas', 7),
#  ('mike.carson', 4),
#  ('eric.saibi', 6),
#  ('j..sturm', 9),
#  ('michelle.cash', 4),
#  ('teb.lokey', 15),
#  ('tracy.geaccone', 12),
#  ('kevin.hyatt', 11),
#  ('darrell.schoolcraft', 13),
#  ('d..steffes', 13),
#  ('cara.semperger', 10),
#  ('sean.crandall', 5),
#  ('cooper.richey', 2),
#  ('diana.scholtes', 5),
#  ('stephanie.panus', 16),
#  ('matt.motley', 4),
#  ('jeff.dasovich', 13),
#  ('barry.tycholiz', 14),
#  ('b..sanders', 6),
#  ('bill.williams', 10),
#  ('craig.dean', 8),
#  ('ryan.slinger', 6),
#  ('lisa.gang', 2),
#  ('geir.solberg', 7),
#  ('doug.gilbert-smith', 15),
#  ('benjamin.rogers', 6),
#  ('james.derrick', 5),
#  ("paul.y'barbo", 10),
#  ('mark.mcconnell', 10),
#  ('tom.donohoe', 4),
#  ('chris.germany', 14),
#  ('john.zufferli', 3),
#  ('chris.dorland', 3),
#  ('frank.ermis', 10),
#  ('kam.keiser', 27),
#  ('martin.cuilla', 5),
#  ('jay.reitmeyer', 15),
#  ('jason.wolfe', 12),
#  ('l..gay', 7),
#  ('mark.whitt', 13),
#  ('j..farmer', 4),
#  ('m..forney', 5),
#  ('judy.townsend', 4),
#  ('scott.hendrickson', 5),
#  ('john.hodge', 17),
#  ('susan.bailey', 5),
#  ('c..giron', 5),
#  ('e..haedicke', 14),
#  ('legal <.taylor@', 14),
#  ('gerald.nemec', 21),
#  ('danny.mccarty', 6),
#  ('sara.shackleton', 15),
#  ('marie.heard', 12),
#  ('tana.jones', 11),
#  ('elizabeth.sager', 13),
#  ('brad.mckay', 7),
#  ('juan.hernandez', 4),
#  ('debra.perlingiere', 12),
#  ('kay.mann', 6),
#  ('keith.holst', 8),
#  ('mike.swerzbin', 6),
#  ('peter.keavey', 7),
#  ('tori.kuykendall', 5),
#  ('lavorato', 19),
#  ('robert.badeer', 1),
#  ('jonathan.mckay', 5),
#  ('w..pereira', 1),
#  ('h..lewis', 5),
#  ('t..lucci', 8),
#  ('mike.maggi', 6),
#  ('larry.may', 13),
#  ('joe.parks', 10),
#  ('andy.zipper', 16),
#  ('albert.meyers', 5),
#  ('theresa.staab', 6),
#  ('kevin.ruscitti', 2),
#  ('phillip.platter', 3),
#  ('holden.salisbury', 8),
#  ('jeff.skilling', 5),
#  ('matt.smith', 5),
#  ('geoff.storey', 5),
#  ('kim.ward', 9),
#  ('jason.williams', 2)]

# %%
# focus only on emails received
list(g.in_degree())
# Out:
# [('greg.whalley', 16),
#  ('k..allen', 2),
#  ('louise.kitchen', 2),
#  ('errol.mclaughlin', 5),
#  ('john.arnold', 6),
#  ('mike.grigsby', 6),
#  ('john.griffith', 0),
#  ('dutch.quigley', 6),
#  ('s..shively', 8),
#  ('richard.shapiro', 2),
#  ('harry.arora', 3),
#  ('sally.beck', 5),
#  ('matthew.lenhart', 1),
#  ('eric.bass', 5),
#  ('a..martin', 16),
#  ('m..love', 3),
#  ('monique.sanchez', 3),
#  ('charles.weldon', 2),
#  ('jeff.king', 1),
#  ('don.baughman', 1),
#  ('w..delainey', 1),
#  ('w..white', 6),
#  ('rod.hayslett', 7),
#  ('rick.buy', 10),
#  ('m..presto', 1),
#  ('robert.benson', 6),
#  ('dana.davis', 0),
#  ('joe.quenet', 0),
#  ('susan.scott', 8),
#  ('michelle.lokay', 5),
#  ('lynn.blair', 5),
#  ('lindy.donoho', 14),
#  ('shelley.corman', 11),
#  ('kimberly.watson', 11),
#  ('bill.rapp', 8),
#  ('scott.neal', 10),
#  ('f..brawner', 6),
#  ('jim.schwieger', 0),
#  ('vladi.pimenov', 7),
#  ('andrea.ring', 1),
#  ('l..mims', 4),
#  ('j.kaminski', 1),
#  ('j..kean', 3),
#  ('a..shankman', 0),
#  ('stanley.horton', 2),
#  ('kenneth.lay', 14),
#  ('f..campbell', 4),
#  ('joe.stepenovitch', 2),
#  ('d..thomas', 5),
#  ('mike.carson', 3),
#  ('eric.saibi', 5),
#  ('j..sturm', 4),
#  ('michelle.cash', 1),
#  ('teb.lokey', 11),
#  ('tracy.geaccone', 7),
#  ('kevin.hyatt', 1),
#  ('darrell.schoolcraft', 7),
#  ('d..steffes', 6),
#  ('cara.semperger', 0),
#  ('sean.crandall', 5),
#  ('cooper.richey', 1),
#  ('diana.scholtes', 1),
#  ('stephanie.panus', 3),
#  ('matt.motley', 2),
#  ('jeff.dasovich', 5),
#  ('barry.tycholiz', 9),
#  ('b..sanders', 3),
#  ('bill.williams', 6),
#  ('craig.dean', 6),
#  ('ryan.slinger', 2),
#  ('lisa.gang', 0),
#  ('geir.solberg', 4),
#  ('doug.gilbert-smith', 7),
#  ('benjamin.rogers', 4),
#  ('james.derrick', 2),
#  ("paul.y'barbo", 5),
#  ('mark.mcconnell', 3),
#  ('tom.donohoe', 2),
#  ('chris.germany', 6),
#  ('john.zufferli', 1),
#  ('chris.dorland', 1),
#  ('frank.ermis', 8),
#  ('kam.keiser', 8),
#  ('martin.cuilla', 0),
#  ('jay.reitmeyer', 12),
#  ('jason.wolfe', 9),
#  ('l..gay', 4),
#  ('mark.whitt', 6),
#  ('j..farmer', 1),
#  ('m..forney', 3),
#  ('judy.townsend', 3),
#  ('scott.hendrickson', 2),
#  ('john.hodge', 16),
#  ('susan.bailey', 0),
#  ('c..giron', 3),
#  ('e..haedicke', 10),
#  ('legal <.taylor@', 8),
#  ('gerald.nemec', 12),
#  ('danny.mccarty', 4),
#  ('sara.shackleton', 8),
#  ('marie.heard', 6),
#  ('tana.jones', 6),
#  ('elizabeth.sager', 10),
#  ('brad.mckay', 4),
#  ('juan.hernandez', 4),
#  ('debra.perlingiere', 4),
#  ('kay.mann', 0),
#  ('keith.holst', 4),
#  ('mike.swerzbin', 5),
#  ('peter.keavey', 7),
#  ('tori.kuykendall', 2),
#  ('lavorato', 19),
#  ('robert.badeer', 0),
#  ('jonathan.mckay', 0),
#  ('w..pereira', 0),
#  ('h..lewis', 4),
#  ('t..lucci', 2),
#  ('mike.maggi', 5),
#  ('larry.may', 11),
#  ('joe.parks', 8),
#  ('andy.zipper', 9),
#  ('albert.meyers', 2),
#  ('theresa.staab', 2),
#  ('kevin.ruscitti', 1),
#  ('phillip.platter', 2),
#  ('holden.salisbury', 8),
#  ('jeff.skilling', 5),
#  ('matt.smith', 5),
#  ('geoff.storey', 5),
#  ('kim.ward', 9),
#  ('jason.williams', 2)]

# %%
# focus only on emails received
list(g.out_degree())
# Out:
# [('greg.whalley', 2),
#  ('k..allen', 8),
#  ('louise.kitchen', 29),
#  ('errol.mclaughlin', 6),
#  ('john.arnold', 8),
#  ('mike.grigsby', 22),
#  ('john.griffith', 8),
#  ('dutch.quigley', 4),
#  ('s..shively', 8),
#  ('richard.shapiro', 8),
#  ('harry.arora', 2),
#  ('sally.beck', 18),
#  ('matthew.lenhart', 8),
#  ('eric.bass', 6),
#  ('a..martin', 4),
#  ('m..love', 9),
#  ('monique.sanchez', 11),
#  ('charles.weldon', 4),
#  ('jeff.king', 2),
#  ('don.baughman', 5),
#  ('w..delainey', 5),
#  ('w..white', 8),
#  ('rod.hayslett', 10),
#  ('rick.buy', 4),
#  ('m..presto', 12),
#  ('robert.benson', 0),
#  ('dana.davis', 3),
#  ('joe.quenet', 1),
#  ('susan.scott', 5),
#  ('michelle.lokay', 11),
#  ('lynn.blair', 8),
#  ('lindy.donoho', 8),
#  ('shelley.corman', 7),
#  ('kimberly.watson', 10),
#  ('bill.rapp', 6),
#  ('scott.neal', 10),
#  ('f..brawner', 2),
#  ('jim.schwieger', 7),
#  ('vladi.pimenov', 2),
#  ('andrea.ring', 1),
#  ('l..mims', 3),
#  ('j.kaminski', 3),
#  ('j..kean', 8),
#  ('a..shankman', 6),
#  ('stanley.horton', 9),
#  ('kenneth.lay', 5),
#  ('f..campbell', 1),
#  ('joe.stepenovitch', 4),
#  ('d..thomas', 2),
#  ('mike.carson', 1),
#  ('eric.saibi', 1),
#  ('j..sturm', 5),
#  ('michelle.cash', 3),
#  ('teb.lokey', 4),
#  ('tracy.geaccone', 5),
#  ('kevin.hyatt', 10),
#  ('darrell.schoolcraft', 6),
#  ('d..steffes', 7),
#  ('cara.semperger', 10),
#  ('sean.crandall', 0),
#  ('cooper.richey', 1),
#  ('diana.scholtes', 4),
#  ('stephanie.panus', 13),
#  ('matt.motley', 2),
#  ('jeff.dasovich', 8),
#  ('barry.tycholiz', 5),
#  ('b..sanders', 3),
#  ('bill.williams', 4),
#  ('craig.dean', 2),
#  ('ryan.slinger', 4),
#  ('lisa.gang', 2),
#  ('geir.solberg', 3),
#  ('doug.gilbert-smith', 8),
#  ('benjamin.rogers', 2),
#  ('james.derrick', 3),
#  ("paul.y'barbo", 5),
#  ('mark.mcconnell', 7),
#  ('tom.donohoe', 2),
#  ('chris.germany', 8),
#  ('john.zufferli', 2),
#  ('chris.dorland', 2),
#  ('frank.ermis', 2),
#  ('kam.keiser', 19),
#  ('martin.cuilla', 5),
#  ('jay.reitmeyer', 3),
#  ('jason.wolfe', 3),
#  ('l..gay', 3),
#  ('mark.whitt', 7),
#  ('j..farmer', 3),
#  ('m..forney', 2),
#  ('judy.townsend', 1),
#  ('scott.hendrickson', 3),
#  ('john.hodge', 1),
#  ('susan.bailey', 5),
#  ('c..giron', 2),
#  ('e..haedicke', 4),
#  ('legal <.taylor@', 6),
#  ('gerald.nemec', 9),
#  ('danny.mccarty', 2),
#  ('sara.shackleton', 7),
#  ('marie.heard', 6),
#  ('tana.jones', 5),
#  ('elizabeth.sager', 3),
#  ('brad.mckay', 3),
#  ('juan.hernandez', 0),
#  ('debra.perlingiere', 8),
#  ('kay.mann', 6),
#  ('keith.holst', 4),
#  ('mike.swerzbin', 1),
#  ('peter.keavey', 0),
#  ('tori.kuykendall', 3),
#  ('lavorato', 0),
#  ('robert.badeer', 1),
#  ('jonathan.mckay', 5),
#  ('w..pereira', 1),
#  ('h..lewis', 1),
#  ('t..lucci', 6),
#  ('mike.maggi', 1),
#  ('larry.may', 2),
#  ('joe.parks', 2),
#  ('andy.zipper', 7),
#  ('albert.meyers', 3),
#  ('theresa.staab', 4),
#  ('kevin.ruscitti', 1),
#  ('phillip.platter', 1),
#  ('holden.salisbury', 0),
#  ('jeff.skilling', 0),
#  ('matt.smith', 0),
#  ('geoff.storey', 0),
#  ('kim.ward', 0),
#  ('jason.williams', 0)]

# %%
# directed 
# U = source, v = target
g.number_of_edges('greg.whalley', 'k..allen')
# Out:
# 1

# %%
# whio did Greg W send email to?
list(g.successors('greg.whalley'))
# Out:
# ['k..allen', 'rick.buy']

# %%
# whio did Greg W send email to?
list(g.predecessors('greg.whalley'))
# Out:
# ['richard.shapiro',
#  'stanley.horton',
#  'j.kaminski',
#  'louise.kitchen',
#  'j..kean',
#  'kenneth.lay',
#  'w..delainey',
#  'sally.beck',
#  'andy.zipper',
#  'rick.buy',
#  'a..shankman',
#  'h..lewis',
#  'tom.donohoe',
#  'jim.schwieger',
#  'k..allen',
#  'james.derrick']

# %% [markdown]
# # Shortest path, cliques, centrality measures and all that

# %%
# find the shortest path between two people
nx.shortest_path(g, source = 'greg.whalley', target = 'kenneth.lay')
# Out:
# ['greg.whalley', 'rick.buy', 'kenneth.lay']

# %%
nx.shortest_path(g, source = 'kenneth.lay', target = 'greg.whalley')
# Out:
# ['kenneth.lay', 'greg.whalley']

# %%
# find maximum clieque
approximation.clique.max_clique(g)
# Out:
# {'legal <.taylor@',
#  'marie.heard',
#  'sara.shackleton',
#  'stephanie.panus',
#  'tana.jones'}

# %%
# how dense is our graph?
# density of 1 -- it's all a complete network (clique)
# density of 0 -- a disconnected graph
nx.density(g)
# Out:
# 0.037345860246623605

# %% [markdown]
# # Finding important node

# %%
# degree centrality number of neigbouring nodes over the number of potential neighbours (i.e. rest of graph)
#between 0 -1
de = nx.degree_centrality(g)
sorted_de = sorted(de.items(), key = lambda x: x[1], reverse = True)
sorted_de
# Out:
# [('louise.kitchen', 0.23846153846153847),
#  ('mike.grigsby', 0.2153846153846154),
#  ('kam.keiser', 0.2076923076923077),
#  ('sally.beck', 0.17692307692307693),
#  ('lindy.donoho', 0.16923076923076924),
#  ('kimberly.watson', 0.16153846153846155),
#  ('gerald.nemec', 0.16153846153846155),
#  ('a..martin', 0.15384615384615385),
#  ('scott.neal', 0.15384615384615385),
#  ('kenneth.lay', 0.14615384615384616),
#  ('lavorato', 0.14615384615384616),
#  ('greg.whalley', 0.13846153846153847),
#  ('shelley.corman', 0.13846153846153847),
#  ('rod.hayslett', 0.13076923076923078),
#  ('john.hodge', 0.13076923076923078),
#  ('s..shively', 0.12307692307692308),
#  ('michelle.lokay', 0.12307692307692308),
#  ('stephanie.panus', 0.12307692307692308),
#  ('andy.zipper', 0.12307692307692308),
#  ('teb.lokey', 0.11538461538461539),
#  ('doug.gilbert-smith', 0.11538461538461539),
#  ('jay.reitmeyer', 0.11538461538461539),
#  ('sara.shackleton', 0.11538461538461539),
#  ('john.arnold', 0.1076923076923077),
#  ('monique.sanchez', 0.1076923076923077),
#  ('w..white', 0.1076923076923077),
#  ('rick.buy', 0.1076923076923077),
#  ('bill.rapp', 0.1076923076923077),
#  ('barry.tycholiz', 0.1076923076923077),
#  ('chris.germany', 0.1076923076923077),
#  ('e..haedicke', 0.1076923076923077),
#  ('legal <.taylor@', 0.1076923076923077),
#  ('m..presto', 0.1),
#  ('susan.scott', 0.1),
#  ('lynn.blair', 0.1),
#  ('darrell.schoolcraft', 0.1),
#  ('d..steffes', 0.1),
#  ('jeff.dasovich', 0.1),
#  ('mark.whitt', 0.1),
#  ('elizabeth.sager', 0.1),
#  ('larry.may', 0.1),
#  ('m..love', 0.09230769230769231),
#  ('tracy.geaccone', 0.09230769230769231),
#  ('jason.wolfe', 0.09230769230769231),
#  ('marie.heard', 0.09230769230769231),
#  ('debra.perlingiere', 0.09230769230769231),
#  ('errol.mclaughlin', 0.08461538461538462),
#  ('eric.bass', 0.08461538461538462),
#  ('j..kean', 0.08461538461538462),
#  ('stanley.horton', 0.08461538461538462),
#  ('kevin.hyatt', 0.08461538461538462),
#  ('tana.jones', 0.08461538461538462),
#  ('k..allen', 0.07692307692307693),
#  ('dutch.quigley', 0.07692307692307693),
#  ('richard.shapiro', 0.07692307692307693),
#  ('cara.semperger', 0.07692307692307693),
#  ('bill.williams', 0.07692307692307693),
#  ("paul.y'barbo", 0.07692307692307693),
#  ('mark.mcconnell', 0.07692307692307693),
#  ('frank.ermis', 0.07692307692307693),
#  ('joe.parks', 0.07692307692307693),
#  ('matthew.lenhart', 0.06923076923076923),
#  ('vladi.pimenov', 0.06923076923076923),
#  ('j..sturm', 0.06923076923076923),
#  ('kim.ward', 0.06923076923076923),
#  ('john.griffith', 0.06153846153846154),
#  ('f..brawner', 0.06153846153846154),
#  ('craig.dean', 0.06153846153846154),
#  ('keith.holst', 0.06153846153846154),
#  ('t..lucci', 0.06153846153846154),
#  ('holden.salisbury', 0.06153846153846154),
#  ('jim.schwieger', 0.05384615384615385),
#  ('l..mims', 0.05384615384615385),
#  ('d..thomas', 0.05384615384615385),
#  ('geir.solberg', 0.05384615384615385),
#  ('l..gay', 0.05384615384615385),
#  ('brad.mckay', 0.05384615384615385),
#  ('peter.keavey', 0.05384615384615385),
#  ('charles.weldon', 0.046153846153846156),
#  ('don.baughman', 0.046153846153846156),
#  ('w..delainey', 0.046153846153846156),
#  ('robert.benson', 0.046153846153846156),
#  ('a..shankman', 0.046153846153846156),
#  ('joe.stepenovitch', 0.046153846153846156),
#  ('eric.saibi', 0.046153846153846156),
#  ('b..sanders', 0.046153846153846156),
#  ('ryan.slinger', 0.046153846153846156),
#  ('benjamin.rogers', 0.046153846153846156),
#  ('danny.mccarty', 0.046153846153846156),
#  ('kay.mann', 0.046153846153846156),
#  ('mike.swerzbin', 0.046153846153846156),
#  ('mike.maggi', 0.046153846153846156),
#  ('theresa.staab', 0.046153846153846156),
#  ('harry.arora', 0.038461538461538464),
#  ('f..campbell', 0.038461538461538464),
#  ('sean.crandall', 0.038461538461538464),
#  ('diana.scholtes', 0.038461538461538464),
#  ('james.derrick', 0.038461538461538464),
#  ('martin.cuilla', 0.038461538461538464),
#  ('m..forney', 0.038461538461538464),
#  ('scott.hendrickson', 0.038461538461538464),
#  ('susan.bailey', 0.038461538461538464),
#  ('c..giron', 0.038461538461538464),
#  ('tori.kuykendall', 0.038461538461538464),
#  ('jonathan.mckay', 0.038461538461538464),
#  ('h..lewis', 0.038461538461538464),
#  ('albert.meyers', 0.038461538461538464),
#  ('jeff.skilling', 0.038461538461538464),
#  ('matt.smith', 0.038461538461538464),
#  ('geoff.storey', 0.038461538461538464),
#  ('j.kaminski', 0.03076923076923077),
#  ('mike.carson', 0.03076923076923077),
#  ('michelle.cash', 0.03076923076923077),
#  ('matt.motley', 0.03076923076923077),
#  ('tom.donohoe', 0.03076923076923077),
#  ('j..farmer', 0.03076923076923077),
#  ('judy.townsend', 0.03076923076923077),
#  ('juan.hernandez', 0.03076923076923077),
#  ('jeff.king', 0.023076923076923078),
#  ('dana.davis', 0.023076923076923078),
#  ('john.zufferli', 0.023076923076923078),
#  ('chris.dorland', 0.023076923076923078),
#  ('phillip.platter', 0.023076923076923078),
#  ('andrea.ring', 0.015384615384615385),
#  ('cooper.richey', 0.015384615384615385),
#  ('lisa.gang', 0.015384615384615385),
#  ('kevin.ruscitti', 0.015384615384615385),
#  ('jason.williams', 0.015384615384615385),
#  ('joe.quenet', 0.007692307692307693),
#  ('robert.badeer', 0.007692307692307693),
#  ('w..pereira', 0.007692307692307693)]

# %%
# betweennees centrality - how many shortest parths go through the node in question over the total shortest paths
de = nx.betweenness_centrality(g)
sorted_de = sorted(de.items(), key = lambda x: x[1], reverse = True)
sorted_de
# Out:
# [('sally.beck', 0.11891229150439925),
#  ('kam.keiser', 0.10425551654478371),
#  ('jeff.dasovich', 0.10157857822436735),
#  ('barry.tycholiz', 0.09534573439260739),
#  ('doug.gilbert-smith', 0.09173401357198575),
#  ('mike.grigsby', 0.08357457510792202),
#  ('gerald.nemec', 0.07062186119540394),
#  ('kenneth.lay', 0.05839367011716742),
#  ('w..white', 0.05747749719505868),
#  ('susan.scott', 0.05681057700568854),
#  ('d..steffes', 0.05472775418698314),
#  ('lindy.donoho', 0.05326974456807773),
#  ('rod.hayslett', 0.05048431104694472),
#  ('a..martin', 0.045218671150039094),
#  ('j..kean', 0.04313445963448459),
#  ('greg.whalley', 0.0428123827538389),
#  ('e..haedicke', 0.04147436076742335),
#  ('chris.germany', 0.041295379663858885),
#  ('andy.zipper', 0.041223472578570966),
#  ('rick.buy', 0.039135776305423566),
#  ('louise.kitchen', 0.037618216628066636),
#  ('eric.bass', 0.03501994163815639),
#  ('mark.whitt', 0.034127507083073196),
#  ('stephanie.panus', 0.03375256430054915),
#  ('benjamin.rogers', 0.03280132873156128),
#  ('scott.neal', 0.032064459639962115),
#  ('j..sturm', 0.03135300940928112),
#  ('joe.parks', 0.028781164260791192),
#  ('keith.holst', 0.028135412794204756),
#  ('jay.reitmeyer', 0.02758304058457135),
#  ('jason.wolfe', 0.02507498093067332),
#  ('shelley.corman', 0.02434940873612182),
#  ('errol.mclaughlin', 0.023897142743296587),
#  ('debra.perlingiere', 0.023634945386381213),
#  ('k..allen', 0.023333275913776805),
#  ('bill.williams', 0.022878155436294973),
#  ('m..love', 0.022745404139627237),
#  ('s..shively', 0.022325325161839396),
#  ('sara.shackleton', 0.021816022189463814),
#  ('legal <.taylor@', 0.02164574063053491),
#  ('mike.swerzbin', 0.019802226197575035),
#  ('w..delainey', 0.01916126724266259),
#  ("paul.y'barbo", 0.018590952300793544),
#  ('larry.may', 0.017887579689905272),
#  ('dutch.quigley', 0.01733314358695817),
#  ('tom.donohoe', 0.016602106174415748),
#  ('tana.jones', 0.015695880113432464),
#  ('john.zufferli', 0.01319178237782889),
#  ('d..thomas', 0.013174584972438282),
#  ('elizabeth.sager', 0.012868906594073722),
#  ('teb.lokey', 0.012472536545433193),
#  ('b..sanders', 0.011825198090851044),
#  ('john.arnold', 0.011336949011367616),
#  ('john.hodge', 0.011190343522667935),
#  ('joe.stepenovitch', 0.008787648613230009),
#  ('marie.heard', 0.008266799943112687),
#  ('kimberly.watson', 0.00810027622243336),
#  ('monique.sanchez', 0.007979007674893185),
#  ('f..brawner', 0.0079386849154291),
#  ('lynn.blair', 0.00787965031882604),
#  ('l..mims', 0.007301648788326124),
#  ('jeff.king', 0.007052275889485191),
#  ('chris.dorland', 0.006618962432915922),
#  ('albert.meyers', 0.006618962432915922),
#  ('vladi.pimenov', 0.006485484799438291),
#  ('richard.shapiro', 0.0061151452072740085),
#  ('judy.townsend', 0.005452133058055288),
#  ('h..lewis', 0.00541108573920927),
#  ('frank.ermis', 0.005285975867371216),
#  ('scott.hendrickson', 0.005242354544680126),
#  ('stanley.horton', 0.0049978336659384755),
#  ('michelle.lokay', 0.004966806417695285),
#  ('m..forney', 0.0048484848484848485),
#  ('j..farmer', 0.004824256277744649),
#  ('darrell.schoolcraft', 0.004449413635460147),
#  ('danny.mccarty', 0.004343059938632252),
#  ('harry.arora', 0.0035523604799096767),
#  ('craig.dean', 0.003398926654740608),
#  ('kevin.hyatt', 0.003358006913039397),
#  ('l..gay', 0.003066000901078756),
#  ('brad.mckay', 0.0028876937016471893),
#  ('tracy.geaccone', 0.002731032798116877),
#  ('mark.mcconnell', 0.0024140960357204606),
#  ('matt.motley', 0.00241337043662625),
#  ('c..giron', 0.002352646846490896),
#  ('bill.rapp', 0.0019175198848723001),
#  ('michelle.cash', 0.001683755355490597),
#  ('t..lucci', 0.0015826744315116407),
#  ('charles.weldon', 0.0013905216230797627),
#  ('eric.saibi', 0.0013323820881960416),
#  ('don.baughman', 0.001148876962830451),
#  ('f..campbell', 0.0011230371695487977),
#  ('tori.kuykendall', 0.0010724014648356495),
#  ('theresa.staab', 0.0010080832173855428),
#  ('j.kaminski', 0.000985225600610216),
#  ('james.derrick', 0.000967998409858875),
#  ('m..presto', 0.0009652993899796852),
#  ('kevin.ruscitti', 0.0007622739018087856),
#  ('cooper.richey', 0.0005501604338813643),
#  ('matthew.lenhart', 0.0003538550497405596),
#  ('mike.maggi', 5.16795865633075e-05),
#  ('ryan.slinger', 3.975352812562115e-05),
#  ('geir.solberg', 3.975352812562115e-05),
#  ('mike.carson', 1.9876764062810574e-05),
#  ('john.griffith', 0.0),
#  ('robert.benson', 0.0),
#  ('dana.davis', 0.0),
#  ('joe.quenet', 0.0),
#  ('jim.schwieger', 0.0),
#  ('andrea.ring', 0.0),
#  ('a..shankman', 0.0),
#  ('cara.semperger', 0.0),
#  ('sean.crandall', 0.0),
#  ('diana.scholtes', 0.0),
#  ('lisa.gang', 0.0),
#  ('martin.cuilla', 0.0),
#  ('susan.bailey', 0.0),
#  ('juan.hernandez', 0.0),
#  ('kay.mann', 0.0),
#  ('peter.keavey', 0.0),
#  ('lavorato', 0.0),
#  ('robert.badeer', 0.0),
#  ('jonathan.mckay', 0.0),
#  ('w..pereira', 0.0),
#  ('phillip.platter', 0.0),
#  ('holden.salisbury', 0.0),
#  ('jeff.skilling', 0.0),
#  ('matt.smith', 0.0),
#  ('geoff.storey', 0.0),
#  ('kim.ward', 0.0),
#  ('jason.williams', 0.0)]

# %%
# eigenvector centrality - how connected are they to other well connected people
de = nx.eigenvector_centrality(g)
sorted_de = sorted(de.items(), key = lambda x: x[1], reverse = True)
sorted_de
# Out:
# [('lindy.donoho', 0.43283066536381926),
#  ('kimberly.watson', 0.3764643744636962),
#  ('teb.lokey', 0.36714607505861885),
#  ('shelley.corman', 0.35611871335599127),
#  ('bill.rapp', 0.26578981874451213),
#  ('darrell.schoolcraft', 0.2516221012826095),
#  ('tracy.geaccone', 0.24582863810480315),
#  ('lynn.blair', 0.2395500177731391),
#  ("paul.y'barbo", 0.204359288022253),
#  ('rod.hayslett', 0.1811749175860459),
#  ('michelle.lokay', 0.1767586453045407),
#  ('danny.mccarty', 0.12506981831550812),
#  ('mark.mcconnell', 0.11990368722464134),
#  ('stanley.horton', 0.0626784895718005),
#  ('kevin.hyatt', 0.05305365586966532),
#  ('kenneth.lay', 0.04846076655757223),
#  ('jeff.skilling', 0.04446008142022868),
#  ('gerald.nemec', 0.042826203473133304),
#  ('sally.beck', 0.03338358636133063),
#  ('l..gay', 0.03317046938272752),
#  ('greg.whalley', 0.03091903378599063),
#  ('rick.buy', 0.02841197314012276),
#  ('e..haedicke', 0.021843772735816905),
#  ('kim.ward', 0.020721871191951156),
#  ('jay.reitmeyer', 0.020682637317963583),
#  ('john.hodge', 0.018529925811392366),
#  ('a..martin', 0.017422430971664463),
#  ('lavorato', 0.0167665435496764),
#  ('barry.tycholiz', 0.01570359409289378),
#  ('frank.ermis', 0.01440993361500808),
#  ('mark.whitt', 0.012978537122794863),
#  ('jason.wolfe', 0.01158755264712055),
#  ('joe.parks', 0.01060867556536998),
#  ('sara.shackleton', 0.010377640424195962),
#  ('kam.keiser', 0.009763167322878335),
#  ('elizabeth.sager', 0.009644665702287456),
#  ('s..shively', 0.009128320578303342),
#  ('w..white', 0.008611527045224353),
#  ('larry.may', 0.008500985493943184),
#  ('t..lucci', 0.008314784890585203),
#  ('j..kean', 0.008131448480738485),
#  ('peter.keavey', 0.007934870167859195),
#  ('mike.grigsby', 0.0074216998380423034),
#  ('debra.perlingiere', 0.007321908800505749),
#  ('scott.neal', 0.007315049469489845),
#  ('tana.jones', 0.006997343751638453),
#  ('eric.saibi', 0.006882456032873476),
#  ('legal <.taylor@', 0.00661485867739235),
#  ('j..sturm', 0.006595150179988746),
#  ('harry.arora', 0.00591351283690085),
#  ('juan.hernandez', 0.005833517585358523),
#  ('tom.donohoe', 0.0057835456248458645),
#  ('chris.germany', 0.005434545402673733),
#  ('marie.heard', 0.005415702693798692),
#  ('k..allen', 0.005364228599776185),
#  ('benjamin.rogers', 0.005359416410192798),
#  ('louise.kitchen', 0.005086344987771196),
#  ('susan.scott', 0.004957230059852328),
#  ('jeff.dasovich', 0.004894827419222422),
#  ('judy.townsend', 0.004496609540126315),
#  ('b..sanders', 0.004477725740065415),
#  ('vladi.pimenov', 0.004360201717133226),
#  ('geoff.storey', 0.004308738650172081),
#  ('john.arnold', 0.0041723373291970255),
#  ('andy.zipper', 0.004160963590949067),
#  ('eric.bass', 0.003680171931131725),
#  ('keith.holst', 0.0036683886728212543),
#  ('l..mims', 0.0036119644532164163),
#  ('errol.mclaughlin', 0.0034935226834277677),
#  ('d..steffes', 0.003312692037934642),
#  ('matt.smith', 0.00327528041284132),
#  ('f..brawner', 0.0031986405886520373),
#  ('c..giron', 0.003184393890142088),
#  ('theresa.staab', 0.0031729608948179513),
#  ('doug.gilbert-smith', 0.0028966919023047165),
#  ('robert.benson', 0.0028925675362075714),
#  ('dutch.quigley', 0.0028683961653446647),
#  ('mike.maggi', 0.0028368430549875513),
#  ('mike.carson', 0.0027658373262114846),
#  ('stephanie.panus', 0.002702389918895554),
#  ('tori.kuykendall', 0.0025607313397706033),
#  ('m..love', 0.0024778630768450905),
#  ('h..lewis', 0.002166166154025027),
#  ('mike.swerzbin', 0.0020698476693262746),
#  ('monique.sanchez', 0.0018569047203935403),
#  ('d..thomas', 0.0018405897280814665),
#  ('charles.weldon', 0.0018315565837054343),
#  ('james.derrick', 0.0013920103705672069),
#  ('matt.motley', 0.0013827555124291124),
#  ('john.zufferli', 0.001283027109764601),
#  ('richard.shapiro', 0.0012231078983554438),
#  ('michelle.cash', 0.0012115019996419127),
#  ('f..campbell', 0.0011344394957540443),
#  ('matthew.lenhart', 0.0011059860990820802),
#  ('jason.williams', 0.0010910352824567697),
#  ('andrea.ring', 0.0010901950306155955),
#  ('brad.mckay', 0.0010901950306155955),
#  ('scott.hendrickson', 0.0009725991544887255),
#  ('w..delainey', 0.0007984986911700113),
#  ('m..presto', 0.0007577625532725664),
#  ('joe.stepenovitch', 0.0007484759338554445),
#  ('sean.crandall', 0.0006374024034432876),
#  ('m..forney', 0.000554144639104504),
#  ('j..farmer', 0.0005485294739408333),
#  ('bill.williams', 0.0005380529489234221),
#  ('craig.dean', 0.0005276482792270426),
#  ('j.kaminski', 0.0004936401481348358),
#  ('jeff.king', 0.0004316622994654698),
#  ('cooper.richey', 0.00019116494466501634),
#  ('chris.dorland', 0.00019116494466501634),
#  ('holden.salisbury', 0.00017463170578924857),
#  ('geir.solberg', 9.393678311900128e-05),
#  ('albert.meyers', 8.019735449971278e-05),
#  ('don.baughman', 6.433443490972477e-05),
#  ('ryan.slinger', 1.195629816841649e-05),
#  ('phillip.platter', 9.387152340694326e-29),
#  ('diana.scholtes', 5.21508463371907e-30),
#  ('kevin.ruscitti', 5.21508463371907e-30),
#  ('john.griffith', 1.4900241810625916e-31),
#  ('dana.davis', 1.4900241810625916e-31),
#  ('joe.quenet', 1.4900241810625916e-31),
#  ('jim.schwieger', 1.4900241810625916e-31),
#  ('a..shankman', 1.4900241810625916e-31),
#  ('cara.semperger', 1.4900241810625916e-31),
#  ('lisa.gang', 1.4900241810625916e-31),
#  ('martin.cuilla', 1.4900241810625916e-31),
#  ('susan.bailey', 1.4900241810625916e-31),
#  ('kay.mann', 1.4900241810625916e-31),
#  ('robert.badeer', 1.4900241810625916e-31),
#  ('jonathan.mckay', 1.4900241810625916e-31),
#  ('w..pereira', 1.4900241810625916e-31)]

# %%
# in-degree centrality - 
de = nx.in_degree_centrality(g)
sorted_de = sorted(de.items(), key = lambda x: x[1], reverse = True)
#sorted_de

# %%
# Create a dataframe of the graph nodes  
names_df = pd.DataFrame(list(g.nodes()), columns=['Name'])

# Map it to a dictionary
names_map = names_df['Name'].to_dict()

names_map
# Out:
# {0: 'greg.whalley',
#  1: 'k..allen',
#  2: 'louise.kitchen',
#  3: 'errol.mclaughlin',
#  4: 'john.arnold',
#  5: 'mike.grigsby',
#  6: 'john.griffith',
#  7: 'dutch.quigley',
#  8: 's..shively',
#  9: 'richard.shapiro',
#  10: 'harry.arora',
#  11: 'sally.beck',
#  12: 'matthew.lenhart',
#  13: 'eric.bass',
#  14: 'a..martin',
#  15: 'm..love',
#  16: 'monique.sanchez',
#  17: 'charles.weldon',
#  18: 'jeff.king',
#  19: 'don.baughman',
#  20: 'w..delainey',
#  21: 'w..white',
#  22: 'rod.hayslett',
#  23: 'rick.buy',
#  24: 'm..presto',
#  25: 'robert.benson',
#  26: 'dana.davis',
#  27: 'joe.quenet',
#  28: 'susan.scott',
#  29: 'michelle.lokay',
#  30: 'lynn.blair',
#  31: 'lindy.donoho',
#  32: 'shelley.corman',
#  33: 'kimberly.watson',
#  34: 'bill.rapp',
#  35: 'scott.neal',
#  36: 'f..brawner',
#  37: 'jim.schwieger',
#  38: 'vladi.pimenov',
#  39: 'andrea.ring',
#  40: 'l..mims',
#  41: 'j.kaminski',
#  42: 'j..kean',
#  43: 'a..shankman',
#  44: 'stanley.horton',
#  45: 'kenneth.lay',
#  46: 'f..campbell',
#  47: 'joe.stepenovitch',
#  48: 'd..thomas',
#  49: 'mike.carson',
#  50: 'eric.saibi',
#  51: 'j..sturm',
#  52: 'michelle.cash',
#  53: 'teb.lokey',
#  54: 'tracy.geaccone',
#  55: 'kevin.hyatt',
#  56: 'darrell.schoolcraft',
#  57: 'd..steffes',
#  58: 'cara.semperger',
#  59: 'sean.crandall',
#  60: 'cooper.richey',
#  61: 'diana.scholtes',
#  62: 'stephanie.panus',
#  63: 'matt.motley',
#  64: 'jeff.dasovich',
#  65: 'barry.tycholiz',
#  66: 'b..sanders',
#  67: 'bill.williams',
#  68: 'craig.dean',
#  69: 'ryan.slinger',
#  70: 'lisa.gang',
#  71: 'geir.solberg',
#  72: 'doug.gilbert-smith',
#  73: 'benjamin.rogers',
#  74: 'james.derrick',
#  75: "paul.y'barbo",
#  76: 'mark.mcconnell',
#  77: 'tom.donohoe',
#  78: 'chris.germany',
#  79: 'john.zufferli',
#  80: 'chris.dorland',
#  81: 'frank.ermis',
#  82: 'kam.keiser',
#  83: 'martin.cuilla',
#  84: 'jay.reitmeyer',
#  85: 'jason.wolfe',
#  86: 'l..gay',
#  87: 'mark.whitt',
#  88: 'j..farmer',
#  89: 'm..forney',
#  90: 'judy.townsend',
#  91: 'scott.hendrickson',
#  92: 'john.hodge',
#  93: 'susan.bailey',
#  94: 'c..giron',
#  95: 'e..haedicke',
#  96: 'legal <.taylor@',
#  97: 'gerald.nemec',
#  98: 'danny.mccarty',
#  99: 'sara.shackleton',
#  100: 'marie.heard',
#  101: 'tana.jones',
#  102: 'elizabeth.sager',
#  103: 'brad.mckay',
#  104: 'juan.hernandez',
#  105: 'debra.perlingiere',
#  106: 'kay.mann',
#  107: 'keith.holst',
#  108: 'mike.swerzbin',
#  109: 'peter.keavey',
#  110: 'tori.kuykendall',
#  111: 'lavorato',
#  112: 'robert.badeer',
#  113: 'jonathan.mckay',
#  114: 'w..pereira',
#  115: 'h..lewis',
#  116: 't..lucci',
#  117: 'mike.maggi',
#  118: 'larry.may',
#  119: 'joe.parks',
#  120: 'andy.zipper',
#  121: 'albert.meyers',
#  122: 'theresa.staab',
#  123: 'kevin.ruscitti',
#  124: 'phillip.platter',
#  125: 'holden.salisbury',
#  126: 'jeff.skilling',
#  127: 'matt.smith',
#  128: 'geoff.storey',
#  129: 'kim.ward',
#  130: 'jason.williams'}

# %%
# Create a list of edges - but now with numbers instead of names. We map the names to the numbers using the names_map
# dictionary.

index_tuples = []

for i in range(len(list(g.edges()))):
    index_tuples.append((list(names_map.values()).index(list(g.edges())[i][0]), 
                         list(names_map.values()).index(list(g.edges())[i][1])))
    
    
index_tuples
# Out:
# [(0, 1),
#  (0, 23),
#  (1, 107),
#  (1, 82),
#  (1, 111),
#  (1, 115),
#  (1, 14),
#  (1, 35),
#  (1, 7),
#  (1, 0),
#  (2, 1),
#  (2, 4),
#  (2, 10),
#  (2, 11),
#  (2, 25),
#  (2, 36),
#  (2, 23),
#  (2, 49),
#  (2, 72),
#  (2, 5),
#  (2, 95),
#  (2, 111),
#  (2, 14),
#  (2, 118),
#  (2, 40),
#  (2, 35),
#  (2, 97),
#  (2, 24),
#  (2, 102),
#  (2, 99),
#  (2, 8),
#  (2, 57),
#  (2, 128),
#  (2, 108),
#  (2, 96),
#  (2, 65),
#  (2, 0),
#  (2, 21),
#  (2, 120),
#  (3, 4),
#  (3, 82),
#  (3, 117),
#  (3, 118),
#  (3, 7),
#  (3, 120),
#  (4, 109),
#  (4, 111),
#  (4, 117),
#  (4, 118),
#  (4, 3),
#  (4, 7),
#  (4, 129),
#  (4, 120),
#  (5, 4),
#  (5, 81),
#  (5, 86),
#  (5, 92),
#  (5, 107),
#  (5, 82),
#  (5, 110),
#  (5, 111),
#  (5, 12),
#  (5, 14),
#  (5, 63),
#  (5, 38),
#  (5, 84),
#  (5, 16),
#  (5, 28),
#  (5, 8),
#  (5, 127),
#  (5, 51),
#  (5, 108),
#  (5, 65),
#  (5, 129),
#  (5, 85),
#  (6, 4),
#  (6, 109),
#  (6, 117),
#  (6, 118),
#  (6, 103),
#  (6, 38),
#  (6, 7),
#  (6, 120),
#  (7, 4),
#  (7, 117),
#  (7, 3),
#  (7, 28),
#  (8, 4),
#  (8, 94),
#  (8, 92),
#  (8, 111),
#  (8, 14),
#  (8, 40),
#  (8, 35),
#  (8, 128),
#  (9, 10),
#  (9, 64),
#  (9, 42),
#  (9, 111),
#  (9, 45),
#  (9, 126),
#  (9, 57),
#  (9, 0),
#  (10, 21),
#  (10, 120),
#  (11, 10),
#  (11, 23),
#  (11, 77),
#  (11, 104),
#  (11, 109),
#  (11, 82),
#  (11, 2),
#  (11, 111),
#  (11, 45),
#  (11, 14),
#  (11, 118),
#  (11, 84),
#  (11, 73),
#  (11, 50),
#  (11, 51),
#  (11, 0),
#  (11, 21),
#  (11, 85),
#  (12, 13),
#  (12, 81),
#  (12, 86),
#  (12, 5),
#  (12, 82),
#  (12, 28),
#  (12, 127),
#  (12, 85),
#  (13, 88),
#  (13, 15),
#  (13, 14),
#  (13, 119),
#  (13, 17),
#  (13, 85),
#  (14, 13),
#  (14, 111),
#  (14, 119),
#  (14, 90),
#  (15, 13),
#  (15, 94),
#  (15, 92),
#  (15, 82),
#  (15, 3),
#  (15, 38),
#  (15, 16),
#  (15, 128),
#  (15, 85),
#  (16, 13),
#  (16, 109),
#  (16, 115),
#  (16, 118),
#  (16, 63),
#  (16, 35),
#  (16, 7),
#  (16, 84),
#  (16, 28),
#  (16, 127),
#  (16, 85),
#  (17, 13),
#  (17, 14),
#  (17, 119),
#  (17, 127),
#  (18, 19),
#  (18, 72),
#  (19, 46),
#  (19, 89),
#  (19, 104),
#  (19, 47),
#  (19, 48),
#  (20, 11),
#  (20, 23),
#  (20, 111),
#  (20, 45),
#  (20, 0),
#  (21, 11),
#  (21, 25),
#  (21, 82),
#  (21, 111),
#  (21, 102),
#  (21, 128),
#  (21, 17),
#  (21, 79),
#  (22, 11),
#  (22, 32),
#  (22, 31),
#  (22, 54),
#  (22, 44),
#  (22, 53),
#  (22, 98),
#  (22, 34),
#  (22, 126),
#  (22, 33),
#  (23, 11),
#  (23, 95),
#  (23, 45),
#  (23, 0),
#  (24, 25),
#  (24, 23),
#  (24, 89),
#  (24, 72),
#  (24, 2),
#  (24, 111),
#  (24, 62),
#  (24, 102),
#  (24, 51),
#  (24, 48),
#  (24, 21),
#  (24, 120),
#  (26, 25),
#  (26, 73),
#  (26, 57),
#  (27, 25),
#  (28, 25),
#  (28, 46),
#  (28, 104),
#  (28, 47),
#  (28, 65),
#  (29, 30),
#  (29, 32),
#  (29, 31),
#  (29, 54),
#  (29, 22),
#  (29, 53),
#  (29, 76),
#  (29, 34),
#  (29, 56),
#  (29, 33),
#  (29, 75),
#  (30, 32),
#  (30, 31),
#  (30, 44),
#  (30, 29),
#  (30, 98),
#  (30, 34),
#  (30, 56),
#  (30, 33),
#  (31, 30),
#  (31, 32),
#  (31, 54),
#  (31, 22),
#  (31, 53),
#  (31, 34),
#  (31, 33),
#  (31, 75),
#  (32, 30),
#  (32, 31),
#  (32, 55),
#  (32, 53),
#  (32, 98),
#  (32, 56),
#  (32, 33),
#  (33, 30),
#  (33, 32),
#  (33, 31),
#  (33, 54),
#  (33, 29),
#  (33, 53),
#  (33, 76),
#  (33, 34),
#  (33, 56),
#  (33, 75),
#  (34, 30),
#  (34, 31),
#  (34, 29),
#  (34, 53),
#  (34, 33),
#  (34, 75),
#  (35, 36),
#  (35, 92),
#  (35, 109),
#  (35, 111),
#  (35, 115),
#  (35, 14),
#  (35, 103),
#  (35, 39),
#  (35, 8),
#  (35, 90),
#  (36, 111),
#  (36, 14),
#  (37, 36),
#  (37, 92),
#  (37, 45),
#  (37, 14),
#  (37, 118),
#  (37, 119),
#  (37, 0),
#  (38, 36),
#  (38, 7),
#  (39, 36),
#  (40, 36),
#  (40, 105),
#  (40, 128),
#  (41, 23),
#  (41, 111),
#  (41, 0),
#  (42, 23),
#  (42, 52),
#  (42, 64),
#  (42, 74),
#  (42, 95),
#  (42, 45),
#  (42, 57),
#  (42, 0),
#  (43, 23),
#  (43, 95),
#  (43, 111),
#  (43, 45),
#  (43, 0),
#  (43, 120),
#  (44, 23),
#  (44, 32),
#  (44, 31),
#  (44, 54),
#  (44, 22),
#  (44, 45),
#  (44, 98),
#  (44, 126),
#  (44, 0),
#  (45, 23),
#  (45, 95),
#  (45, 42),
#  (45, 126),
#  (45, 0),
#  (46, 48),
#  (47, 46),
#  (47, 104),
#  (47, 73),
#  (47, 48),
#  (48, 46),
#  (48, 73),
#  (49, 50),
#  (50, 49),
#  (51, 49),
#  (51, 72),
#  (51, 14),
#  (51, 50),
#  (51, 8),
#  (52, 74),
#  (52, 95),
#  (52, 8),
#  (53, 32),
#  (53, 31),
#  (53, 54),
#  (53, 56),
#  (54, 32),
#  (54, 31),
#  (54, 22),
#  (54, 53),
#  (54, 33),
#  (55, 32),
#  (55, 31),
#  (55, 54),
#  (55, 22),
#  (55, 45),
#  (55, 29),
#  (55, 53),
#  (55, 34),
#  (55, 56),
#  (55, 33),
#  (56, 32),
#  (56, 31),
#  (56, 29),
#  (56, 53),
#  (56, 76),
#  (56, 33),
#  (57, 32),
#  (57, 64),
#  (57, 72),
#  (57, 41),
#  (57, 102),
#  (57, 66),
#  (57, 9),
#  (58, 59),
#  (58, 68),
#  (58, 121),
#  (58, 124),
#  (58, 125),
#  (58, 61),
#  (58, 69),
#  (58, 71),
#  (58, 108),
#  (58, 67),
#  (60, 59),
#  (61, 59),
#  (61, 124),
#  (61, 125),
#  (61, 108),
#  (62, 59),
#  (62, 78),
#  (62, 72),
#  (62, 100),
#  (62, 92),
#  (62, 101),
#  (62, 40),
#  (62, 97),
#  (62, 105),
#  (62, 102),
#  (62, 99),
#  (62, 51),
#  (62, 96),
#  (63, 59),
#  (63, 108),
#  (64, 31),
#  (64, 42),
#  (64, 53),
#  (64, 66),
#  (64, 9),
#  (64, 126),
#  (64, 57),
#  (64, 65),
#  (65, 64),
#  (65, 14),
#  (65, 97),
#  (65, 129),
#  (65, 87),
#  (66, 64),
#  (66, 95),
#  (66, 111),
#  (67, 68),
#  (67, 121),
#  (67, 125),
#  (67, 71),
#  (68, 125),
#  (68, 67),
#  (69, 68),
#  (69, 125),
#  (69, 71),
#  (69, 67),
#  (70, 68),
#  (70, 125),
#  (71, 68),
#  (71, 125),
#  (71, 67),
#  (72, 68),
#  (72, 89),
#  (72, 18),
#  (72, 14),
#  (72, 50),
#  (72, 57),
#  (72, 21),
#  (72, 67),
#  (73, 20),
#  (73, 45),
#  (74, 95),
#  (74, 45),
#  (74, 0),
#  (75, 31),
#  (75, 86),
#  (75, 97),
#  (75, 34),
#  (75, 33),
#  (76, 31),
#  (76, 22),
#  (76, 53),
#  (76, 34),
#  (76, 56),
#  (76, 33),
#  (76, 75),
#  (77, 45),
#  (77, 0),
#  (78, 77),
#  (78, 91),
#  (78, 92),
#  (78, 109),
#  (78, 35),
#  (78, 119),
#  (78, 38),
#  (78, 90),
#  (79, 80),
#  (79, 60),
#  (80, 5),
#  (80, 84),
#  (81, 84),
#  (81, 85),
#  (82, 81),
#  (82, 86),
#  (82, 78),
#  (82, 94),
#  (82, 5),
#  (82, 92),
#  (82, 107),
#  (82, 110),
#  (82, 15),
#  (82, 3),
#  (82, 35),
#  (82, 38),
#  (82, 84),
#  (82, 8),
#  (82, 127),
#  (82, 129),
#  (82, 21),
#  (82, 87),
#  (82, 85),
#  (83, 81),
#  (83, 115),
#  (83, 103),
#  (83, 123),
#  (83, 130),
#  (84, 81),
#  (84, 5),
#  (84, 8),
#  (85, 81),
#  (85, 84),
#  (85, 65),
#  (86, 81),
#  (86, 84),
#  (86, 129),
#  (87, 81),
#  (87, 5),
#  (87, 116),
#  (87, 97),
#  (87, 84),
#  (87, 122),
#  (87, 65),
#  (88, 92),
#  (88, 14),
#  (88, 97),
#  (89, 72),
#  (89, 50),
#  (90, 78),
#  (91, 78),
#  (91, 118),
#  (91, 35),
#  (92, 78),
#  (93, 78),
#  (93, 100),
#  (93, 101),
#  (93, 99),
#  (93, 96),
#  (94, 15),
#  (94, 8),
#  (95, 101),
#  (95, 97),
#  (95, 102),
#  (95, 66),
#  (96, 95),
#  (96, 100),
#  (96, 92),
#  (96, 101),
#  (96, 102),
#  (96, 99),
#  (97, 95),
#  (97, 92),
#  (97, 116),
#  (97, 119),
#  (97, 105),
#  (97, 99),
#  (97, 65),
#  (97, 129),
#  (97, 87),
#  (98, 22),
#  (98, 45),
#  (99, 100),
#  (99, 92),
#  (99, 101),
#  (99, 62),
#  (99, 102),
#  (99, 96),
#  (99, 129),
#  (100, 92),
#  (100, 101),
#  (100, 97),
#  (100, 102),
#  (100, 99),
#  (100, 96),
#  (101, 100),
#  (101, 92),
#  (101, 62),
#  (101, 99),
#  (101, 96),
#  (102, 100),
#  (102, 96),
#  (102, 48),
#  (103, 91),
#  (103, 109),
#  (103, 118),
#  (105, 92),
#  (105, 40),
#  (105, 35),
#  (105, 97),
#  (105, 65),
#  (105, 129),
#  (105, 87),
#  (105, 130),
#  (106, 92),
#  (106, 97),
#  (106, 119),
#  (106, 105),
#  (106, 102),
#  (106, 99),
#  (107, 82),
#  (107, 111),
#  (107, 28),
#  (107, 85),
#  (108, 107),
#  (110, 84),
#  (110, 16),
#  (110, 28),
#  (112, 111),
#  (113, 111),
#  (113, 103),
#  (113, 35),
#  (113, 38),
#  (113, 120),
#  (114, 45),
#  (115, 0),
#  (116, 97),
#  (116, 84),
#  (116, 122),
#  (116, 65),
#  (116, 129),
#  (116, 87),
#  (117, 118),
#  (118, 117),
#  (118, 120),
#  (119, 14),
#  (119, 28),
#  (120, 14),
#  (120, 118),
#  (120, 3),
#  (120, 35),
#  (120, 38),
#  (120, 96),
#  (120, 0),
#  (121, 69),
#  (121, 71),
#  (121, 67),
#  (122, 97),
#  (122, 84),
#  (122, 28),
#  (122, 87),
#  (123, 119),
#  (124, 125)]

# %%
# use the spring layout function to assign (x,y,z) coordinates to each of our nodes 

# to maintain shape, we use the same seed = 123
positions = nx.spring_layout(g, dim = 3, seed = 123)
positions
# Out:
# {'greg.whalley': array([ 0.1835852 , -0.08386077, -0.0193002 ]),
#  'k..allen': array([ 0.26738853, -0.06952478, -0.03475717]),
#  'louise.kitchen': array([ 0.01443084,  0.00304238, -0.01601759]),
#  'errol.mclaughlin': array([ 0.13614421, -0.09640792,  0.01123306]),
#  'john.arnold': array([ 0.20408164, -0.02602757,  0.04363202]),
#  'mike.grigsby': array([ 0.1195202 ,  0.09839607, -0.00693157]),
#  'john.griffith': array([ 0.14124665, -0.20677986,  0.22358659]),
#  'dutch.quigley': array([-0.00020456, -0.0713716 , -0.05932842]),
#  's..shively': array([ 0.24883653, -0.26410741,  0.06916514]),
#  'richard.shapiro': array([ 0.26057542, -0.16993544, -0.12921246]),
#  'harry.arora': array([ 0.13028926, -0.0917526 , -0.02006339]),
#  'sally.beck': array([-0.07594141, -0.0464921 ,  0.09509709]),
#  'matthew.lenhart': array([0.14105261, 0.17915181, 0.08976593]),
#  'eric.bass': array([ 0.14657137, -0.01562585,  0.03570792]),
#  'a..martin': array([ 2.44352783e-01, -1.04251219e-01,  4.69336312e-05]),
#  'm..love': array([ 0.13521692, -0.19275685,  0.08594975]),
#  'monique.sanchez': array([ 0.07431334, -0.01805303,  0.20651684]),
#  'charles.weldon': array([0.20890073, 0.14649135, 0.21077927]),
#  'jeff.king': array([-0.33950796,  0.11574756,  0.05313272]),
#  'don.baughman': array([-0.35509882, -0.03377286,  0.03625846]),
#  'w..delainey': array([ 0.2259932 , -0.08493909, -0.05281852]),
#  'w..white': array([ 0.05803759, -0.05434147, -0.08910108]),
#  'rod.hayslett': array([ 0.07406034, -0.20426518, -0.09984196]),
#  'rick.buy': array([ 0.09012175, -0.10029858, -0.00596826]),
#  'm..presto': array([-0.04116674,  0.09769311, -0.07133286]),
#  'robert.benson': array([-0.12909599,  0.36356497, -0.64713605]),
#  'dana.davis': array([ 0.04458431,  0.09443151, -0.31226501]),
#  'joe.quenet': array([-0.1196407 ,  0.33800303, -0.5946223 ]),
#  'susan.scott': array([-0.27264025,  0.02450293, -0.20186678]),
#  'michelle.lokay': array([ 0.02889716, -0.09767454, -0.09925197]),
#  'lynn.blair': array([ 0.05072578, -0.14710918, -0.10147306]),
#  'lindy.donoho': array([ 0.03654296, -0.09867984, -0.10402904]),
#  'shelley.corman': array([ 0.02611866, -0.14850827, -0.0810072 ]),
#  'kimberly.watson': array([ 0.01685591, -0.0785686 , -0.09403051]),
#  'bill.rapp': array([ 0.02196205, -0.06201535, -0.10430881]),
#  'scott.neal': array([ 0.29550208, -0.19823717,  0.19654057]),
#  'f..brawner': array([ 0.40969514, -0.08606341, -0.09465613]),
#  'jim.schwieger': array([ 0.18574144, -0.13646504,  0.0181302 ]),
#  'vladi.pimenov': array([ 0.20600985, -0.07612592, -0.08421172]),
#  'andrea.ring': array([ 0.44025244, -0.08940215, -0.0661659 ]),
#  'l..mims': array([ 0.12423314, -0.2598616 ,  0.07315612]),
#  'j.kaminski': array([ 0.31469061, -0.08197119, -0.08707433]),
#  'j..kean': array([ 0.15526135, -0.10562582, -0.06151062]),
#  'a..shankman': array([ 0.28306782, -0.09798984, -0.07108301]),
#  'stanley.horton': array([ 0.133029  , -0.22375169, -0.11425565]),
#  'kenneth.lay': array([ 0.19463394, -0.21357867, -0.10465374]),
#  'f..campbell': array([ 0.05547063, -0.12844196,  0.03269138]),
#  'joe.stepenovitch': array([-0.24007761, -0.15983389, -0.02734585]),
#  'd..thomas': array([ 0.13623193, -0.15169594, -0.0265611 ]),
#  'mike.carson': array([-0.88756761,  0.50925576,  0.30776501]),
#  'eric.saibi': array([-0.87461851,  0.50155867,  0.2877065 ]),
#  'j..sturm': array([-0.31617289,  0.16297722,  0.1624241 ]),
#  'michelle.cash': array([ 0.2112544 , -0.1454201 ,  0.00379314]),
#  'teb.lokey': array([-0.02553989, -0.12335427, -0.06851588]),
#  'tracy.geaccone': array([ 0.00550835, -0.14193074, -0.08388639]),
#  'kevin.hyatt': array([ 0.05337047, -0.13837233, -0.09335396]),
#  'darrell.schoolcraft': array([-0.01121902, -0.10172203, -0.07923567]),
#  'd..steffes': array([ 0.07792412, -0.00965758, -0.05268316]),
#  'cara.semperger': array([-0.51466896,  0.395269  ,  0.00085643]),
#  'sean.crandall': array([-1.        , -0.04832671,  0.03984977]),
#  'cooper.richey': array([-0.89326173, -0.03931707,  0.03804733]),
#  'diana.scholtes': array([-0.49739696,  0.31481444, -0.02948082]),
#  'stephanie.panus': array([-0.1529749 , -0.03722624,  0.08186364]),
#  'matt.motley': array([-0.41476549, -0.01131541, -0.08529347]),
#  'jeff.dasovich': array([ 0.17138183, -0.13943651, -0.159049  ]),
#  'barry.tycholiz': array([ 0.18373622,  0.1486549 , -0.24720125]),
#  'b..sanders': array([ 0.33108797, -0.07191644, -0.13304046]),
#  'bill.williams': array([-0.59996796,  0.64548048,  0.07712487]),
#  'craig.dean': array([-0.58572878,  0.62701232,  0.06172891]),
#  'ryan.slinger': array([-0.59704043,  0.63328702,  0.06871025]),
#  'lisa.gang': array([-0.58643545,  0.6458442 ,  0.06040607]),
#  'geir.solberg': array([-0.57833084,  0.61838436,  0.07251329]),
#  'doug.gilbert-smith': array([-0.30799599,  0.26038974,  0.06696366]),
#  'benjamin.rogers': array([ 0.23233276, -0.15871227, -0.09172638]),
#  'james.derrick': array([ 0.18721641, -0.11569259, -0.06552015]),
#  "paul.y'barbo": array([ 0.08585326,  0.03445827, -0.14617092]),
#  'mark.mcconnell': array([ 0.03253636, -0.08525427, -0.10880638]),
#  'tom.donohoe': array([ 0.20146245, -0.15909883, -0.06481136]),
#  'chris.germany': array([ 0.14343448, -0.20570252,  0.2325528 ]),
#  'john.zufferli': array([-0.36360384, -0.00473946,  0.02765155]),
#  'chris.dorland': array([0.16715736, 0.0276205 , 0.01712007]),
#  'frank.ermis': array([ 0.21561534, -0.001919  , -0.03859282]),
#  'kam.keiser': array([0.19780495, 0.06776376, 0.03899559]),
#  'martin.cuilla': array([-0.14636067, -0.07623956,  0.27542105]),
#  'jay.reitmeyer': array([ 0.19669643, -0.07083107,  0.02352113]),
#  'jason.wolfe': array([ 0.19918102,  0.04078768, -0.10475232]),
#  'l..gay': array([ 0.19520818,  0.20062993, -0.2355712 ]),
#  'mark.whitt': array([ 0.14543022,  0.06969308, -0.10786277]),
#  'j..farmer': array([ 0.15917413, -0.06014533,  0.07614528]),
#  'm..forney': array([-0.59047725,  0.38034445,  0.17726176]),
#  'judy.townsend': array([ 0.13506847, -0.23919198,  0.28563101]),
#  'scott.hendrickson': array([ 0.20120909, -0.21018387,  0.15054628]),
#  'john.hodge': array([ 0.15661503, -0.22575731,  0.29086867]),
#  'susan.bailey': array([ 0.11174222, -0.05693434,  0.09395705]),
#  'c..giron': array([ 0.19353544, -0.25004648,  0.09481567]),
#  'e..haedicke': array([ 0.16586003, -0.02080257, -0.03080057]),
#  'legal <.taylor@': array([ 0.12897915, -0.06821697,  0.09445334]),
#  'gerald.nemec': array([ 0.11920431,  0.12191326, -0.11906404]),
#  'danny.mccarty': array([ 0.12683142, -0.23973244, -0.11537215]),
#  'sara.shackleton': array([ 0.10197461,  0.0825156 , -0.06341835]),
#  'marie.heard': array([ 0.12151774, -0.0364651 ,  0.0703003 ]),
#  'tana.jones': array([ 0.05609686, -0.06424164,  0.11073054]),
#  'elizabeth.sager': array([ 0.12685482, -0.09972853,  0.04979071]),
#  'brad.mckay': array([ 0.16230965, -0.29511251,  0.37951208]),
#  'juan.hernandez': array([-0.9136284 , -0.17908021, -0.01001682]),
#  'debra.perlingiere': array([-0.05741976,  0.05991719,  0.09305429]),
#  'kay.mann': array([ 0.07765146, -0.02921538,  0.05136387]),
#  'keith.holst': array([ 0.15629462,  0.00079809, -0.15012914]),
#  'mike.swerzbin': array([ 0.17316842,  0.02538817, -0.2097591 ]),
#  'peter.keavey': array([ 0.14182654, -0.41385395,  0.7984369 ]),
#  'tori.kuykendall': array([-0.03237889, -0.01459539, -0.00795907]),
#  'lavorato': array([ 0.5689903 , -0.06737284, -0.19012274]),
#  'robert.badeer': array([ 0.43625266, -0.04717738, -0.1435563 ]),
#  'jonathan.mckay': array([ 0.31295955, -0.15876056,  0.07021419]),
#  'w..pereira': array([ 0.16066225, -0.2600205 , -0.11121515]),
#  'h..lewis': array([ 0.24178568, -0.06344932,  0.01114929]),
#  't..lucci': array([ 0.14453382,  0.18961349, -0.23070241]),
#  'mike.maggi': array([ 0.10685001, -0.25033827, -0.01277626]),
#  'larry.may': array([ 0.16200398, -0.20714139,  0.02746664]),
#  'joe.parks': array([-0.01828915, -0.03735195, -0.10281942]),
#  'andy.zipper': array([ 0.2063575 , -0.12750445,  0.05117105]),
#  'albert.meyers': array([-0.58069222,  0.61336746,  0.09438953]),
#  'theresa.staab': array([ 0.00547166,  0.0249805 , -0.10592251]),
#  'kevin.ruscitti': array([-0.07295524, -0.02376881, -0.14005239]),
#  'phillip.platter': array([-0.67854722,  0.74902072,  0.06826147]),
#  'holden.salisbury': array([-0.69991786,  0.77734354,  0.05808958]),
#  'jeff.skilling': array([ 0.28653461, -0.48955042, -0.2568838 ]),
#  'matt.smith': array([0.3837392 , 0.49270816, 0.6354706 ]),
#  'geoff.storey': array([ 0.03569136, -0.6700789 ,  0.19550581]),
#  'kim.ward': array([ 0.17988762,  0.53608727, -0.56061613]),
#  'jason.williams': array([-0.77472217, -0.0507359 ,  0.78393192])}

# %%
# extract x,y,z values and put them in a list
pos_list = list(positions.values())
pos_list
# Out:
# [array([ 0.1835852 , -0.08386077, -0.0193002 ]),
#  array([ 0.26738853, -0.06952478, -0.03475717]),
#  array([ 0.01443084,  0.00304238, -0.01601759]),
#  array([ 0.13614421, -0.09640792,  0.01123306]),
#  array([ 0.20408164, -0.02602757,  0.04363202]),
#  array([ 0.1195202 ,  0.09839607, -0.00693157]),
#  array([ 0.14124665, -0.20677986,  0.22358659]),
#  array([-0.00020456, -0.0713716 , -0.05932842]),
#  array([ 0.24883653, -0.26410741,  0.06916514]),
#  array([ 0.26057542, -0.16993544, -0.12921246]),
#  array([ 0.13028926, -0.0917526 , -0.02006339]),
#  array([-0.07594141, -0.0464921 ,  0.09509709]),
#  array([0.14105261, 0.17915181, 0.08976593]),
#  array([ 0.14657137, -0.01562585,  0.03570792]),
#  array([ 2.44352783e-01, -1.04251219e-01,  4.69336312e-05]),
#  array([ 0.13521692, -0.19275685,  0.08594975]),
#  array([ 0.07431334, -0.01805303,  0.20651684]),
#  array([0.20890073, 0.14649135, 0.21077927]),
#  array([-0.33950796,  0.11574756,  0.05313272]),
#  array([-0.35509882, -0.03377286,  0.03625846]),
#  array([ 0.2259932 , -0.08493909, -0.05281852]),
#  array([ 0.05803759, -0.05434147, -0.08910108]),
#  array([ 0.07406034, -0.20426518, -0.09984196]),
#  array([ 0.09012175, -0.10029858, -0.00596826]),
#  array([-0.04116674,  0.09769311, -0.07133286]),
#  array([-0.12909599,  0.36356497, -0.64713605]),
#  array([ 0.04458431,  0.09443151, -0.31226501]),
#  array([-0.1196407 ,  0.33800303, -0.5946223 ]),
#  array([-0.27264025,  0.02450293, -0.20186678]),
#  array([ 0.02889716, -0.09767454, -0.09925197]),
#  array([ 0.05072578, -0.14710918, -0.10147306]),
#  array([ 0.03654296, -0.09867984, -0.10402904]),
#  array([ 0.02611866, -0.14850827, -0.0810072 ]),
#  array([ 0.01685591, -0.0785686 , -0.09403051]),
#  array([ 0.02196205, -0.06201535, -0.10430881]),
#  array([ 0.29550208, -0.19823717,  0.19654057]),
#  array([ 0.40969514, -0.08606341, -0.09465613]),
#  array([ 0.18574144, -0.13646504,  0.0181302 ]),
#  array([ 0.20600985, -0.07612592, -0.08421172]),
#  array([ 0.44025244, -0.08940215, -0.0661659 ]),
#  array([ 0.12423314, -0.2598616 ,  0.07315612]),
#  array([ 0.31469061, -0.08197119, -0.08707433]),
#  array([ 0.15526135, -0.10562582, -0.06151062]),
#  array([ 0.28306782, -0.09798984, -0.07108301]),
#  array([ 0.133029  , -0.22375169, -0.11425565]),
#  array([ 0.19463394, -0.21357867, -0.10465374]),
#  array([ 0.05547063, -0.12844196,  0.03269138]),
#  array([-0.24007761, -0.15983389, -0.02734585]),
#  array([ 0.13623193, -0.15169594, -0.0265611 ]),
#  array([-0.88756761,  0.50925576,  0.30776501]),
#  array([-0.87461851,  0.50155867,  0.2877065 ]),
#  array([-0.31617289,  0.16297722,  0.1624241 ]),
#  array([ 0.2112544 , -0.1454201 ,  0.00379314]),
#  array([-0.02553989, -0.12335427, -0.06851588]),
#  array([ 0.00550835, -0.14193074, -0.08388639]),
#  array([ 0.05337047, -0.13837233, -0.09335396]),
#  array([-0.01121902, -0.10172203, -0.07923567]),
#  array([ 0.07792412, -0.00965758, -0.05268316]),
#  array([-0.51466896,  0.395269  ,  0.00085643]),
#  array([-1.        , -0.04832671,  0.03984977]),
#  array([-0.89326173, -0.03931707,  0.03804733]),
#  array([-0.49739696,  0.31481444, -0.02948082]),
#  array([-0.1529749 , -0.03722624,  0.08186364]),
#  array([-0.41476549, -0.01131541, -0.08529347]),
#  array([ 0.17138183, -0.13943651, -0.159049  ]),
#  array([ 0.18373622,  0.1486549 , -0.24720125]),
#  array([ 0.33108797, -0.07191644, -0.13304046]),
#  array([-0.59996796,  0.64548048,  0.07712487]),
#  array([-0.58572878,  0.62701232,  0.06172891]),
#  array([-0.59704043,  0.63328702,  0.06871025]),
#  array([-0.58643545,  0.6458442 ,  0.06040607]),
#  array([-0.57833084,  0.61838436,  0.07251329]),
#  array([-0.30799599,  0.26038974,  0.06696366]),
#  array([ 0.23233276, -0.15871227, -0.09172638]),
#  array([ 0.18721641, -0.11569259, -0.06552015]),
#  array([ 0.08585326,  0.03445827, -0.14617092]),
#  array([ 0.03253636, -0.08525427, -0.10880638]),
#  array([ 0.20146245, -0.15909883, -0.06481136]),
#  array([ 0.14343448, -0.20570252,  0.2325528 ]),
#  array([-0.36360384, -0.00473946,  0.02765155]),
#  array([0.16715736, 0.0276205 , 0.01712007]),
#  array([ 0.21561534, -0.001919  , -0.03859282]),
#  array([0.19780495, 0.06776376, 0.03899559]),
#  array([-0.14636067, -0.07623956,  0.27542105]),
#  array([ 0.19669643, -0.07083107,  0.02352113]),
#  array([ 0.19918102,  0.04078768, -0.10475232]),
#  array([ 0.19520818,  0.20062993, -0.2355712 ]),
#  array([ 0.14543022,  0.06969308, -0.10786277]),
#  array([ 0.15917413, -0.06014533,  0.07614528]),
#  array([-0.59047725,  0.38034445,  0.17726176]),
#  array([ 0.13506847, -0.23919198,  0.28563101]),
#  array([ 0.20120909, -0.21018387,  0.15054628]),
#  array([ 0.15661503, -0.22575731,  0.29086867]),
#  array([ 0.11174222, -0.05693434,  0.09395705]),
#  array([ 0.19353544, -0.25004648,  0.09481567]),
#  array([ 0.16586003, -0.02080257, -0.03080057]),
#  array([ 0.12897915, -0.06821697,  0.09445334]),
#  array([ 0.11920431,  0.12191326, -0.11906404]),
#  array([ 0.12683142, -0.23973244, -0.11537215]),
#  array([ 0.10197461,  0.0825156 , -0.06341835]),
#  array([ 0.12151774, -0.0364651 ,  0.0703003 ]),
#  array([ 0.05609686, -0.06424164,  0.11073054]),
#  array([ 0.12685482, -0.09972853,  0.04979071]),
#  array([ 0.16230965, -0.29511251,  0.37951208]),
#  array([-0.9136284 , -0.17908021, -0.01001682]),
#  array([-0.05741976,  0.05991719,  0.09305429]),
#  array([ 0.07765146, -0.02921538,  0.05136387]),
#  array([ 0.15629462,  0.00079809, -0.15012914]),
#  array([ 0.17316842,  0.02538817, -0.2097591 ]),
#  array([ 0.14182654, -0.41385395,  0.7984369 ]),
#  array([-0.03237889, -0.01459539, -0.00795907]),
#  array([ 0.5689903 , -0.06737284, -0.19012274]),
#  array([ 0.43625266, -0.04717738, -0.1435563 ]),
#  array([ 0.31295955, -0.15876056,  0.07021419]),
#  array([ 0.16066225, -0.2600205 , -0.11121515]),
#  array([ 0.24178568, -0.06344932,  0.01114929]),
#  array([ 0.14453382,  0.18961349, -0.23070241]),
#  array([ 0.10685001, -0.25033827, -0.01277626]),
#  array([ 0.16200398, -0.20714139,  0.02746664]),
#  array([-0.01828915, -0.03735195, -0.10281942]),
#  array([ 0.2063575 , -0.12750445,  0.05117105]),
#  array([-0.58069222,  0.61336746,  0.09438953]),
#  array([ 0.00547166,  0.0249805 , -0.10592251]),
#  array([-0.07295524, -0.02376881, -0.14005239]),
#  array([-0.67854722,  0.74902072,  0.06826147]),
#  array([-0.69991786,  0.77734354,  0.05808958]),
#  array([ 0.28653461, -0.48955042, -0.2568838 ]),
#  array([0.3837392 , 0.49270816, 0.6354706 ]),
#  array([ 0.03569136, -0.6700789 ,  0.19550581]),
#  array([ 0.17988762,  0.53608727, -0.56061613]),
#  array([-0.77472217, -0.0507359 ,  0.78393192])]

# %%
# setting node attributes
# we want to vary the node size based on some centrality measure

# degree centrality
nx.set_node_attributes(g, nx.degree_centrality(g), 'Degree Centrality')

# Betweenness centrality
nx.set_node_attributes(g, nx.betweenness_centrality(g), 'Betweenness Centrality')

# eigenvector centrality
nx.set_node_attributes(g, nx.eigenvector_centrality(g), 'Eigenvector Centrality')

# in_degre centrality
nx.set_node_attributes(g, nx.in_degree_centrality(g), 'In-degree Centrality')

# %% [markdown]
# # Betweenness Centrality
# The bigger the node on the graph, the more 'between-central' it is.

# %%
# Number of nodes
N2=len(g.nodes())

# Number of edges
L2=len(g.edges())

# Setting coordinates of the nodes based on the values from the pos_list we created earlier
Xn=[pos_list[k][0] for k in range(N2)]# x-coordinates 
Yn=[pos_list[k][1] for k in range(N2)]# y-coordinates
Zn=[pos_list[k][2] for k in range(N2)]# z-coordinates

# Setting coordinates of edge beginnings and ends
Xe=[]
Ye=[]
Ze=[]
for e in index_tuples:
    Xe+=[pos_list[e[0]][0],pos_list[e[1]][0], None]# x-coordinates of edge ends
    Ye+=[pos_list[e[0]][1],pos_list[e[1]][1], None]  
    Ze+=[pos_list[e[0]][2],pos_list[e[1]][2], None]
    

###### Feel free to experiment with the scale variable!

# Scale of the node size. You can change this to change the sizes of the nodes depending on what you find most useful.    
scale2 = [220*x for x in nx.get_node_attributes(g, 'Betweenness Centrality').values()]

######

    
# Creating a 'trace' (plotly object) for the edges
trace1=go.Scatter3d(x=Xe,
               y=Ye,
               z=Ze,
               mode='lines',
               line=dict(color='rgb(125,125,125)', width=1),
               hoverinfo='none'
               )

# Creating a trace for the nodes 
trace2=go.Scatter3d(x=Xn,
               y=Yn,
               z=Zn,
               mode='markers',
               name='actors',
               marker=dict(symbol='circle',
                             size= scale2,
                             colorscale='Viridis',
                             line=dict(color='rgb(50,50,50)', width=0.5)
                             ),
               text=list(nx.get_node_attributes(g, 'Betweenness Centrality').keys()),
               hoverinfo='text'
               )

# Modifying axis properties
axis=dict(showbackground=False,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

# Modifying layout properties
layout = go.Layout(
         title="Betweenness centrality in the Enron employee network",
         width=1000,
         height=1000,
         showlegend=False,
         scene=dict(
             xaxis=dict(axis),
             yaxis=dict(axis),
             zaxis=dict(axis),
        ),
     margin=dict(
        t=100
    ),
    hovermode='closest',
    annotations=[
           dict(
           showarrow=False,
            text="",
            xref='paper',
            yref='paper',
            x=0,
            y=0.1,
            xanchor='left',
            yanchor='bottom',
            font=dict(
            size=14
            )
            )
        ],    )

# Combining traces in one list
data=[trace1, trace2]

# Passing the list to the Figure() function
fig2=go.Figure(data=data, layout=layout)

# %%
offpy(fig2, filename='Enron Emails -- Betweenness Centrality')

# Or to view online
#py.iplot(fig2, filename='Enron Emails -- Betweenness Centrality')
# Out:
# T:\Anaconda3\lib\site-packages\plotly\offline\offline.py:635: UserWarning:
#
# Your filename `Enron Emails -- Betweenness Centrality` didn't end with .html. Adding .html to the end of your file.
# 'file://C:\\Users\\Decoded\\Downloads\\network-analysis-helpers-master\\Enron Emails -- Betweenness Centrality.html'

# %% [markdown]
# # Eigenvector Centrality
# The bigger the node on the graph, the more connected it is to other well-connected nodes.

# %%
# Number of nodes
N2=len(g.nodes())

# Number of edges
L2=len(g.edges())

# Setting coordinates of the nodes based on the values from the pos_list we created earlier
Xn=[pos_list[k][0] for k in range(N2)]# x-coordinates 
Yn=[pos_list[k][1] for k in range(N2)]# y-coordinates
Zn=[pos_list[k][2] for k in range(N2)]# z-coordinates

# Setting coordinates of edge beginnings and ends
Xe=[]
Ye=[]
Ze=[]
for e in index_tuples:
    Xe+=[pos_list[e[0]][0],pos_list[e[1]][0], None]# x-coordinates of edge ends
    Ye+=[pos_list[e[0]][1],pos_list[e[1]][1], None]  
    Ze+=[pos_list[e[0]][2],pos_list[e[1]][2], None]
    

###### Feel free to experiment with the scale variable!

# Scale of the node size. You can change this to change the sizes of the nodes depending on what you find most useful.    
scale3 = [75*x for x in nx.get_node_attributes(g, 'Eigenvector Centrality').values()]

######

    
# Creating a 'trace' (plotly object) for the edges
trace1=go.Scatter3d(x=Xe,
               y=Ye,
               z=Ze,
               mode='lines',
               line=dict(color='rgb(125,125,125)', width=1),
               hoverinfo='none'
               )

# Creating a trace for the nodes 
trace2=go.Scatter3d(x=Xn,
               y=Yn,
               z=Zn,
               mode='markers',
               name='actors',
               marker=dict(symbol='circle',
                             size= scale3,
                             colorscale='Viridis',
                             line=dict(color='rgb(50,50,50)', width=0.5)
                             ),
               text=list(nx.get_node_attributes(g, 'Eigenvector Centrality').keys()),
               hoverinfo='text'
               )

# Modifying axis properties
axis=dict(showbackground=False,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

# Modifying layout properties
layout = go.Layout(
         title="Eigenvector centrality in the Enron employee network",
         width=1000,
         height=1000,
         showlegend=False,
         scene=dict(
             xaxis=dict(axis),
             yaxis=dict(axis),
             zaxis=dict(axis),
        ),
     margin=dict(
        t=100
    ),
    hovermode='closest',
    annotations=[
           dict(
           showarrow=False,
            text="",
            xref='paper',
            yref='paper',
            x=0,
            y=0.1,
            xanchor='left',
            yanchor='bottom',
            font=dict(
            size=14
            )
            )
        ],    )

# Combining traces in one list
data=[trace1, trace2]

# Passing the list to the Figure() function
fig3=go.Figure(data=data, layout=layout)

# %%
offpy(fig3, filename='Enron Emails -- Eigenvector Centrality')

# Or to view the graph online
#py.iplot(fig3, filename='Enron Emails -- Eigenvector Centrality')
# Out:
# T:\Anaconda3\lib\site-packages\plotly\offline\offline.py:635: UserWarning:
#
# Your filename `Enron Emails -- Eigenvector Centrality` didn't end with .html. Adding .html to the end of your file.
# 'file://C:\\Users\\Decoded\\Downloads\\network-analysis-helpers-master\\Enron Emails -- Eigenvector Centrality.html'

# %% [markdown]
# # In-degree Centrality
# The bigger the node on the graph, the more degree-central it is -- but only in terms of receiving emails, i.e. the 'in' direction.

# %%
# Number of nodes
N2=len(g.nodes())

# Number of edges
L2=len(g.edges())

# Setting coordinates of the nodes based on the values from the pos_list we created earlier
Xn=[pos_list[k][0] for k in range(N2)]# x-coordinates 
Yn=[pos_list[k][1] for k in range(N2)]# y-coordinates
Zn=[pos_list[k][2] for k in range(N2)]# z-coordinates

# Setting coordinates of edge beginnings and ends
Xe=[]
Ye=[]
Ze=[]
for e in index_tuples:
    Xe+=[pos_list[e[0]][0],pos_list[e[1]][0], None]# x-coordinates of edge ends
    Ye+=[pos_list[e[0]][1],pos_list[e[1]][1], None]  
    Ze+=[pos_list[e[0]][2],pos_list[e[1]][2], None]
    

###### Feel free to experiment with the scale variable!

# Scale of the node size. You can change this to change the sizes of the nodes depending on what you find most useful.    
scale4 = [160*x for x in nx.get_node_attributes(g, 'In-degree Centrality').values()]

######

    
# Creating a 'trace' (plotly object) for the edges
trace1=go.Scatter3d(x=Xe,
               y=Ye,
               z=Ze,
               mode='lines',
               line=dict(color='rgb(125,125,125)', width=1),
               hoverinfo='none'
               )

# Creating a trace for the nodes 
trace2=go.Scatter3d(x=Xn,
               y=Yn,
               z=Zn,
               mode='markers',
               name='actors',
               marker=dict(symbol='circle',
                             size= scale4,
                             colorscale='Viridis',
                             line=dict(color='rgb(50,50,50)', width=0.5)
                             ),
               text=list(nx.get_node_attributes(g, 'In-degree Centrality').keys()),
               hoverinfo='text'
               )

# Modifying axis properties
axis=dict(showbackground=False,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

# Modifying layout properties
layout = go.Layout(
         title="In-degree centrality in the Enron employee network",
         width=1000,
         height=1000,
         showlegend=False,
         scene=dict(
             xaxis=dict(axis),
             yaxis=dict(axis),
             zaxis=dict(axis),
        ),
     margin=dict(
        t=100
    ),
    hovermode='closest',
    annotations=[
           dict(
           showarrow=False,
            text="",
            xref='paper',
            yref='paper',
            x=0,
            y=0.1,
            xanchor='left',
            yanchor='bottom',
            font=dict(
            size=14
            )
            )
        ],    )

# Combining traces in one list
data=[trace1, trace2]

# Passing the list to the Figure() function
fig4=go.Figure(data=data, layout=layout)

# %%
offpy(fig4, filename='Enron Emails -- In-degree Centrality')

# Or to view the graph online
#py.iplot(fig4, filename='Enron Emails -- In-degree Centrality')
# Out:
# T:\Anaconda3\lib\site-packages\plotly\offline\offline.py:635: UserWarning:
#
# Your filename `Enron Emails -- In-degree Centrality` didn't end with .html. Adding .html to the end of your file.
# 'file://C:\\Users\\Decoded\\Downloads\\network-analysis-helpers-master\\Enron Emails -- In-degree Centrality.html'
